# %%
from helper_code import *
from team_code import *
import numpy as np, scipy as sp, scipy.stats, os, sys, joblib
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_class_weight
import os
import tqdm
import numpy as np
import tensorflow as tf
from scipy import signal
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
# Find data files.

data_folder = "./data/dataset/data/training_data/"

# Find the patient data files.
patient_files = find_patient_files(data_folder)
num_patient_files = len(patient_files)

if num_patient_files==0:
    raise Exception('No data was provided.')

# Create a folder for the model if it does not already exist.
#os.makedirs(model_folder, exist_ok=True)
#TODO: remove this:
#classes = ['Present', 'Unknown', 'Absent']
#num_classes = len(classes)

murmur_classes = ['Present', 'Unknown', 'Absent']
num_murmur_classes = len(murmur_classes)
outcome_classes = ['Abnormal', 'Normal']
num_outcome_classes = len(outcome_classes)

# Extract the features and labels.
#if verbose >= 1:
#    print('Extracting features and labels from the Challenge data...')

data = []
murmurs = list()
outcomes = list()
NEW_FREQUENCY = 100

for i in tqdm.tqdm(range(num_patient_files)):
    # Load the current patient data and recordings.
    current_patient_data = load_patient_data(patient_files[i])
    current_recordings, freq = load_recordings(data_folder, current_patient_data, get_frequencies=True)
    for j in range(len(current_recordings)):
        data.append(signal.resample(current_recordings[j], int((len(current_recordings[j])/freq[j]) * NEW_FREQUENCY)))
        current_auscultation_location = current_patient_data.split('\n')[1:len(current_recordings)+1][j].split(" ")[0]
        all_murmur_locations = get_murmur_locations(current_patient_data).split("+")
        current_murmur = np.zeros(num_murmur_classes, dtype=int)
        if get_murmur(current_patient_data) == "Present":
            if current_auscultation_location in all_murmur_locations:
                current_murmur[0] = 1
            else:
                pass
        elif get_murmur(current_patient_data) == "Unknown":
            current_murmur[1] = 1
        elif get_murmur(current_patient_data) == "Absent":
            current_murmur[2] = 1
        murmurs.append(current_murmur)

        current_outcome = np.zeros(num_outcome_classes, dtype=int)
        outcome = get_outcome(current_patient_data)
        if outcome in outcome_classes:
            j = outcome_classes.index(outcome)
            current_outcome[j] = 1
        outcomes.append(current_outcome)

data_padded = pad_array(data)
# Out:
# 100%|██████████| 942/942 [00:31<00:00, 29.70it/s]

# %%
np.expand_dims(data_padded,2).shape
# Out:
# (3163, 6451, 1)

# %%
data_padded.shape
# Out:
# (3163, 6451)

# %%
def pad_array(data):
    max_len = 0
    for i in data:
        if len(i) > max_len:
            max_len = len(i)
    new_arr = np.zeros((len(data),max_len))
    for j in range(len(data)):
        new_arr[j,:len(data[j])] = data[j]
    return new_arr

# %%
max_len = 0
for i in data:
    if len(i) > max_len:
        max_len = len(i)

# %%
len(data)
# Out:
# 3163

# %%
new_arr = np.zeros((len(data),max_len))

# %%
for j in range(len(data)):
    new_arr[j,:len(data[j])] = data[j]

# %%
import matplotlib.pyplot as plt

# %%
keras.utils.pad_sequences(data, padding='pre', truncating='pre', value=0.0, maxlen=32256)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Bjorn\Documents\Github\Heart-murmur-detection-2022-private\new_nb_test.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000015?line=0'>1</a> keras.utils.pad_sequences(data, padding='pre', truncating='pre', value=0.0, maxlen=32256)
#
# NameError: name 'keras' is not defined

# %%
max_len = 0
for i in data:
    if len(i) > max_len:
        max_len = len(i)

# %%
max_len
# Out:
# 32256

# %%
len(murmurs)
# Out:
# 3163

# %%
np.unique(np.argmax(murmurs, axis=1), return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int64), array([ 616,  156, 2391], dtype=int64))

# %%
np.unique(np.argmax(outcomes, axis=1), return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([1531, 1632], dtype=int64))

# %%
get_murmur_locations(current_patient_data).split("+")
# Out:
# ['nan']

# %%
np.argmax(np.array([[1,0,0],[0,1,0],[0,0,1]]),axis=1)
# Out:
# array([0, 1, 2], dtype=int64)

# %%
np.sum(np.array([[0.2,0.7,0.1],[0.3,0.5,0.2],[0.1,0.8,0.1]]),axis=0)/3
# Out:
# array([0.2       , 0.66666667, 0.13333333])

# %%
np.sum(np.array([0.4,0.3,0.5,0.7,0.9]))/5
# Out:
# 0.5599999999999999

# %%
np.array([[1,0,0],[0,1,0],[0,0,1]])

# %%
current_patient_data.split('\n')[1:4+1][0].split(" ")[0]
# Out:
# 'AV'

# %%
current_recordings
# Out:
# [array([1653, 3815, 3101, ...,  187,  348,   53], dtype=int16),
#  array([32596, 28290,  8851, ...,  6449,  6299,  7167], dtype=int16),
#  array([   244,  -3588, -22579, ...,   -207,   -205,   -204], dtype=int16),
#  array([5039, 5952, 5754, ...,  344,  229,   87], dtype=int16)]

# %%
load_patient_data(patient_files[i])
# Out:
# '9979 4 4000\nAV 9979_AV.hea 9979_AV.wav 9979_AV.tsv\nPV 9979_PV.hea 9979_PV.wav 9979_PV.tsv\nTV 9979_TV.hea 9979_TV.wav 9979_TV.tsv\nMV 9979_MV.hea 9979_MV.wav 9979_MV.tsv\n#Age: Child\n#Sex: Female\n#Height: 103.0\n#Weight: 13.1\n#Pregnancy status: False\n#Murmur: Present\n#Murmur locations: AV+MV+PV+TV\n#Most audible location: TV\n#Systolic murmur timing: Holosystolic\n#Systolic murmur shape: Diamond\n#Systolic murmur grading: III/VI\n#Systolic murmur pitch: High\n#Systolic murmur quality: Harsh\n#Diastolic murmur timing: nan\n#Diastolic murmur shape: nan\n#Diastolic murmur grading: nan\n#Diastolic murmur pitch: nan\n#Diastolic murmur quality: nan\n#Outcome: Abnormal\n#Campaign: CC2015\n#Additional ID: nan\n'

# %%
current_location = current_patient_data.split('\n')[1:len(current_recordings)+1][j].split(" ")[0]

# %%
all_murmur_locations = get_murmur_locations(current_patient_data).split("+")

# %%
current_location in all_murmur_locations
# Out:
# False

# %%
current_patient_data
# Out:
# '50635 4 4000\nAV 50635_AV.hea 50635_AV.wav 50635_AV.tsv\nPV 50635_PV.hea 50635_PV.wav 50635_PV.tsv\nTV 50635_TV.hea 50635_TV.wav 50635_TV.tsv\nMV 50635_MV.hea 50635_MV.wav 50635_MV.tsv\n#Age: nan\n#Sex: Female\n#Height: nan\n#Weight: nan\n#Pregnancy status: True\n#Murmur: Absent\n#Murmur locations: nan\n#Most audible location: nan\n#Systolic murmur timing: nan\n#Systolic murmur shape: nan\n#Systolic murmur grading: nan\n#Systolic murmur pitch: nan\n#Systolic murmur quality: nan\n#Diastolic murmur timing: nan\n#Diastolic murmur shape: nan\n#Diastolic murmur grading: nan\n#Diastolic murmur pitch: nan\n#Diastolic murmur quality: nan\n#Outcome: Normal\n#Campaign: CC2014\n#Additional ID: nan\n'

# %%
murmur = get_murmur(current_patient_data)
murmur
# Out:
# 'Absent'

# %%
    current_murmur = np.zeros(num_murmur_classes, dtype=int)
    murmur = get_murmur(current_patient_data)
    if murmur in murmur_classes:
        j = murmur_classes.index(murmur)
        current_murmur[j] = 1
    murmurs.append(current_murmur)

# %%
from helper_code import *
from team_code import *
import numpy as np, scipy as sp, scipy.stats, os, sys, joblib
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_class_weight
import os
import tqdm
import numpy as np
import tensorflow as tf
from scipy import signal
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
# Find data files.

data_folder = "./data/dataset/data/training_data/"

# %%
patient_files = find_patient_files(data_folder)

# %%
patient_files
# Out:
# ['./data/dataset/data/training_data/2530.txt',
#  './data/dataset/data/training_data/9979.txt',
#  './data/dataset/data/training_data/9983.txt',
#  './data/dataset/data/training_data/13918.txt',
#  './data/dataset/data/training_data/14241.txt',
#  './data/dataset/data/training_data/14998.txt',
#  './data/dataset/data/training_data/23625.txt',
#  './data/dataset/data/training_data/24160.txt',
#  './data/dataset/data/training_data/29045.txt',
#  './data/dataset/data/training_data/29378.txt',
#  './data/dataset/data/training_data/31737.txt',
#  './data/dataset/data/training_data/33151.txt',
#  './data/dataset/data/training_data/36327.txt',
#  './data/dataset/data/training_data/38337.txt',
#  './data/dataset/data/training_data/39043.txt',
#  './data/dataset/data/training_data/39403.txt',
#  './data/dataset/data/training_data/39456.txt',
#  './data/dataset/data/training_data/40058.txt',
#  './data/dataset/data/training_data/40798.txt',
#  './data/dataset/data/training_data/40840.txt',
#  './data/dataset/data/training_data/43852.txt',
#  './data/dataset/data/training_data/44514.txt',
#  './data/dataset/data/training_data/45843.txt',
#  './data/dataset/data/training_data/46065.txt',
#  './data/dataset/data/training_data/46532.txt',
#  './data/dataset/data/training_data/46579.txt',
#  './data/dataset/data/training_data/46778.txt',
#  './data/dataset/data/training_data/47002.txt',
#  './data/dataset/data/training_data/49558.txt',
#  './data/dataset/data/training_data/49561.txt',
#  './data/dataset/data/training_data/49562.txt',
#  './data/dataset/data/training_data/49568.txt',
#  './data/dataset/data/training_data/49572.txt',
#  './data/dataset/data/training_data/49574.txt',
#  './data/dataset/data/training_data/49577.txt',
#  './data/dataset/data/training_data/49585.txt',
#  './data/dataset/data/training_data/49595.txt',
#  './data/dataset/data/training_data/49598.txt',
#  './data/dataset/data/training_data/49607.txt',
#  './data/dataset/data/training_data/49610.txt',
#  './data/dataset/data/training_data/49618.txt',
#  './data/dataset/data/training_data/49622.txt',
#  './data/dataset/data/training_data/49627.txt',
#  './data/dataset/data/training_data/49628.txt',
#  './data/dataset/data/training_data/49630.txt',
#  './data/dataset/data/training_data/49631.txt',
#  './data/dataset/data/training_data/49638.txt',
#  './data/dataset/data/training_data/49641.txt',
#  './data/dataset/data/training_data/49653.txt',
#  './data/dataset/data/training_data/49659.txt',
#  './data/dataset/data/training_data/49661.txt',
#  './data/dataset/data/training_data/49669.txt',
#  './data/dataset/data/training_data/49678.txt',
#  './data/dataset/data/training_data/49683.txt',
#  './data/dataset/data/training_data/49687.txt',
#  './data/dataset/data/training_data/49691.txt',
#  './data/dataset/data/training_data/49704.txt',
#  './data/dataset/data/training_data/49712.txt',
#  './data/dataset/data/training_data/49719.txt',
#  './data/dataset/data/training_data/49729.txt',
#  './data/dataset/data/training_data/49735.txt',
#  './data/dataset/data/training_data/49745.txt',
#  './data/dataset/data/training_data/49748.txt',
#  './data/dataset/data/training_data/49751.txt',
#  './data/dataset/data/training_data/49754.txt',
#  './data/dataset/data/training_data/49761.txt',
#  './data/dataset/data/training_data/49776.txt',
#  './data/dataset/data/training_data/49808.txt',
#  './data/dataset/data/training_data/49821.txt',
#  './data/dataset/data/training_data/49823.txt',
#  './data/dataset/data/training_data/49824.txt',
#  './data/dataset/data/training_data/49829.txt',
#  './data/dataset/data/training_data/49832.txt',
#  './data/dataset/data/training_data/49838.txt',
#  './data/dataset/data/training_data/49839.txt',
#  './data/dataset/data/training_data/49842.txt',
#  './data/dataset/data/training_data/49850.txt',
#  './data/dataset/data/training_data/49853.txt',
#  './data/dataset/data/training_data/49854.txt',
#  './data/dataset/data/training_data/49873.txt',
#  './data/dataset/data/training_data/49876.txt',
#  './data/dataset/data/training_data/49896.txt',
#  './data/dataset/data/training_data/49897.txt',
#  './data/dataset/data/training_data/49900.txt',
#  './data/dataset/data/training_data/49930.txt',
#  './data/dataset/data/training_data/49931.txt',
#  './data/dataset/data/training_data/49946.txt',
#  './data/dataset/data/training_data/49952.txt',
#  './data/dataset/data/training_data/49959.txt',
#  './data/dataset/data/training_data/49960.txt',
#  './data/dataset/data/training_data/49963.txt',
#  './data/dataset/data/training_data/49966.txt',
#  './data/dataset/data/training_data/49968.txt',
#  './data/dataset/data/training_data/49969.txt',
#  './data/dataset/data/training_data/49970.txt',
#  './data/dataset/data/training_data/49974.txt',
#  './data/dataset/data/training_data/49978.txt',
#  './data/dataset/data/training_data/49979.txt',
#  './data/dataset/data/training_data/49980.txt',
#  './data/dataset/data/training_data/49983.txt',
#  './data/dataset/data/training_data/49986.txt',
#  './data/dataset/data/training_data/49987.txt',
#  './data/dataset/data/training_data/49988.txt',
#  './data/dataset/data/training_data/49989.txt',
#  './data/dataset/data/training_data/49990.txt',
#  './data/dataset/data/training_data/49993.txt',
#  './data/dataset/data/training_data/49994.txt',
#  './data/dataset/data/training_data/49995.txt',
#  './data/dataset/data/training_data/49998.txt',
#  './data/dataset/data/training_data/49999.txt',
#  './data/dataset/data/training_data/50001.txt',
#  './data/dataset/data/training_data/50004.txt',
#  './data/dataset/data/training_data/50005.txt',
#  './data/dataset/data/training_data/50006.txt',
#  './data/dataset/data/training_data/50007.txt',
#  './data/dataset/data/training_data/50008.txt',
#  './data/dataset/data/training_data/50009.txt',
#  './data/dataset/data/training_data/50012.txt',
#  './data/dataset/data/training_data/50014.txt',
#  './data/dataset/data/training_data/50015.txt',
#  './data/dataset/data/training_data/50017.txt',
#  './data/dataset/data/training_data/50018.txt',
#  './data/dataset/data/training_data/50023.txt',
#  './data/dataset/data/training_data/50026.txt',
#  './data/dataset/data/training_data/50027.txt',
#  './data/dataset/data/training_data/50029.txt',
#  './data/dataset/data/training_data/50030.txt',
#  './data/dataset/data/training_data/50032.txt',
#  './data/dataset/data/training_data/50034.txt',
#  './data/dataset/data/training_data/50037.txt',
#  './data/dataset/data/training_data/50043.txt',
#  './data/dataset/data/training_data/50047.txt',
#  './data/dataset/data/training_data/50048.txt',
#  './data/dataset/data/training_data/50049.txt',
#  './data/dataset/data/training_data/50053.txt',
#  './data/dataset/data/training_data/50054.txt',
#  './data/dataset/data/training_data/50056.txt',
#  './data/dataset/data/training_data/50057.txt',
#  './data/dataset/data/training_data/50061.txt',
#  './data/dataset/data/training_data/50066.txt',
#  './data/dataset/data/training_data/50067.txt',
#  './data/dataset/data/training_data/50070.txt',
#  './data/dataset/data/training_data/50072.txt',
#  './data/dataset/data/training_data/50074.txt',
#  './data/dataset/data/training_data/50075.txt',
#  './data/dataset/data/training_data/50076.txt',
#  './data/dataset/data/training_data/50077.txt',
#  './data/dataset/data/training_data/50078.txt',
#  './data/dataset/data/training_data/50079.txt',
#  './data/dataset/data/training_data/50080.txt',
#  './data/dataset/data/training_data/50085.txt',
#  './data/dataset/data/training_data/50086.txt',
#  './data/dataset/data/training_data/50089.txt',
#  './data/dataset/data/training_data/50092.txt',
#  './data/dataset/data/training_data/50094.txt',
#  './data/dataset/data/training_data/50096.txt',
#  './data/dataset/data/training_data/50099.txt',
#  './data/dataset/data/training_data/50100.txt',
#  './data/dataset/data/training_data/50103.txt',
#  './data/dataset/data/training_data/50104.txt',
#  './data/dataset/data/training_data/50105.txt',
#  './data/dataset/data/training_data/50109.txt',
#  './data/dataset/data/training_data/50111.txt',
#  './data/dataset/data/training_data/50113.txt',
#  './data/dataset/data/training_data/50115.txt',
#  './data/dataset/data/training_data/50116.txt',
#  './data/dataset/data/training_data/50117.txt',
#  './data/dataset/data/training_data/50118.txt',
#  './data/dataset/data/training_data/50119.txt',
#  './data/dataset/data/training_data/50121.txt',
#  './data/dataset/data/training_data/50122.txt',
#  './data/dataset/data/training_data/50123.txt',
#  './data/dataset/data/training_data/50125.txt',
#  './data/dataset/data/training_data/50126.txt',
#  './data/dataset/data/training_data/50127.txt',
#  './data/dataset/data/training_data/50128.txt',
#  './data/dataset/data/training_data/50129.txt',
#  './data/dataset/data/training_data/50133.txt',
#  './data/dataset/data/training_data/50136.txt',
#  './data/dataset/data/training_data/50137.txt',
#  './data/dataset/data/training_data/50138.txt',
#  './data/dataset/data/training_data/50141.txt',
#  './data/dataset/data/training_data/50142.txt',
#  './data/dataset/data/training_data/50143.txt',
#  './data/dataset/data/training_data/50145.txt',
#  './data/dataset/data/training_data/50146.txt',
#  './data/dataset/data/training_data/50149.txt',
#  './data/dataset/data/training_data/50150.txt',
#  './data/dataset/data/training_data/50151.txt',
#  './data/dataset/data/training_data/50152.txt',
#  './data/dataset/data/training_data/50153.txt',
#  './data/dataset/data/training_data/50155.txt',
#  './data/dataset/data/training_data/50159.txt',
#  './data/dataset/data/training_data/50160.txt',
#  './data/dataset/data/training_data/50161.txt',
#  './data/dataset/data/training_data/50164.txt',
#  './data/dataset/data/training_data/50165.txt',
#  './data/dataset/data/training_data/50166.txt',
#  './data/dataset/data/training_data/50168.txt',
#  './data/dataset/data/training_data/50174.txt',
#  './data/dataset/data/training_data/50204.txt',
#  './data/dataset/data/training_data/50206.txt',
#  './data/dataset/data/training_data/50207.txt',
#  './data/dataset/data/training_data/50209.txt',
#  './data/dataset/data/training_data/50210.txt',
#  './data/dataset/data/training_data/50213.txt',
#  './data/dataset/data/training_data/50214.txt',
#  './data/dataset/data/training_data/50216.txt',
#  './data/dataset/data/training_data/50217.txt',
#  './data/dataset/data/training_data/50218.txt',
#  './data/dataset/data/training_data/50219.txt',
#  './data/dataset/data/training_data/50220.txt',
#  './data/dataset/data/training_data/50221.txt',
#  './data/dataset/data/training_data/50222.txt',
#  './data/dataset/data/training_data/50225.txt',
#  './data/dataset/data/training_data/50228.txt',
#  './data/dataset/data/training_data/50229.txt',
#  './data/dataset/data/training_data/50230.txt',
#  './data/dataset/data/training_data/50231.txt',
#  './data/dataset/data/training_data/50233.txt',
#  './data/dataset/data/training_data/50238.txt',
#  './data/dataset/data/training_data/50239.txt',
#  './data/dataset/data/training_data/50241.txt',
#  './data/dataset/data/training_data/50244.txt',
#  './data/dataset/data/training_data/50247.txt',
#  './data/dataset/data/training_data/50248.txt',
#  './data/dataset/data/training_data/50249.txt',
#  './data/dataset/data/training_data/50250.txt',
#  './data/dataset/data/training_data/50251.txt',
#  './data/dataset/data/training_data/50254.txt',
#  './data/dataset/data/training_data/50255.txt',
#  './data/dataset/data/training_data/50256.txt',
#  './data/dataset/data/training_data/50258.txt',
#  './data/dataset/data/training_data/50260.txt',
#  './data/dataset/data/training_data/50261.txt',
#  './data/dataset/data/training_data/50263.txt',
#  './data/dataset/data/training_data/50264.txt',
#  './data/dataset/data/training_data/50271.txt',
#  './data/dataset/data/training_data/50272.txt',
#  './data/dataset/data/training_data/50273.txt',
#  './data/dataset/data/training_data/50275.txt',
#  './data/dataset/data/training_data/50276.txt',
#  './data/dataset/data/training_data/50277.txt',
#  './data/dataset/data/training_data/50278.txt',
#  './data/dataset/data/training_data/50280.txt',
#  './data/dataset/data/training_data/50281.txt',
#  './data/dataset/data/training_data/50284.txt',
#  './data/dataset/data/training_data/50285.txt',
#  './data/dataset/data/training_data/50289.txt',
#  './data/dataset/data/training_data/50291.txt',
#  './data/dataset/data/training_data/50295.txt',
#  './data/dataset/data/training_data/50296.txt',
#  './data/dataset/data/training_data/50297.txt',
#  './data/dataset/data/training_data/50298.txt',
#  './data/dataset/data/training_data/50299.txt',
#  './data/dataset/data/training_data/50300.txt',
#  './data/dataset/data/training_data/50303.txt',
#  './data/dataset/data/training_data/50304.txt',
#  './data/dataset/data/training_data/50306.txt',
#  './data/dataset/data/training_data/50311.txt',
#  './data/dataset/data/training_data/50312.txt',
#  './data/dataset/data/training_data/50314.txt',
#  './data/dataset/data/training_data/50316.txt',
#  './data/dataset/data/training_data/50317.txt',
#  './data/dataset/data/training_data/50318.txt',
#  './data/dataset/data/training_data/50319.txt',
#  './data/dataset/data/training_data/50321.txt',
#  './data/dataset/data/training_data/50323.txt',
#  './data/dataset/data/training_data/50325.txt',
#  './data/dataset/data/training_data/50326.txt',
#  './data/dataset/data/training_data/50327.txt',
#  './data/dataset/data/training_data/50330.txt',
#  './data/dataset/data/training_data/50331.txt',
#  './data/dataset/data/training_data/50332.txt',
#  './data/dataset/data/training_data/50334.txt',
#  './data/dataset/data/training_data/50335.txt',
#  './data/dataset/data/training_data/50336.txt',
#  './data/dataset/data/training_data/50337.txt',
#  './data/dataset/data/training_data/50339.txt',
#  './data/dataset/data/training_data/50341.txt',
#  './data/dataset/data/training_data/50342.txt',
#  './data/dataset/data/training_data/50343.txt',
#  './data/dataset/data/training_data/50345.txt',
#  './data/dataset/data/training_data/50348.txt',
#  './data/dataset/data/training_data/50349.txt',
#  './data/dataset/data/training_data/50350.txt',
#  './data/dataset/data/training_data/50352.txt',
#  './data/dataset/data/training_data/50354.txt',
#  './data/dataset/data/training_data/50359.txt',
#  './data/dataset/data/training_data/50375.txt',
#  './data/dataset/data/training_data/50379.txt',
#  './data/dataset/data/training_data/50384.txt',
#  './data/dataset/data/training_data/50385.txt',
#  './data/dataset/data/training_data/50386.txt',
#  './data/dataset/data/training_data/50388.txt',
#  './data/dataset/data/training_data/50391.txt',
#  './data/dataset/data/training_data/50393.txt',
#  './data/dataset/data/training_data/50619.txt',
#  './data/dataset/data/training_data/50620.txt',
#  './data/dataset/data/training_data/50621.txt',
#  './data/dataset/data/training_data/50624.txt',
#  './data/dataset/data/training_data/50625.txt',
#  './data/dataset/data/training_data/50626.txt',
#  './data/dataset/data/training_data/50628.txt',
#  './data/dataset/data/training_data/50629.txt',
#  './data/dataset/data/training_data/50631.txt',
#  './data/dataset/data/training_data/50635.txt',
#  './data/dataset/data/training_data/50636.txt',
#  './data/dataset/data/training_data/50639.txt',
#  './data/dataset/data/training_data/50640.txt',
#  './data/dataset/data/training_data/50641.txt',
#  './data/dataset/data/training_data/50643.txt',
#  './data/dataset/data/training_data/50644.txt',
#  './data/dataset/data/training_data/50645.txt',
#  './data/dataset/data/training_data/50646.txt',
#  './data/dataset/data/training_data/50647.txt',
#  './data/dataset/data/training_data/50649.txt',
#  './data/dataset/data/training_data/50652.txt',
#  './data/dataset/data/training_data/50654.txt',
#  './data/dataset/data/training_data/50655.txt',
#  './data/dataset/data/training_data/50656.txt',
#  './data/dataset/data/training_data/50657.txt',
#  './data/dataset/data/training_data/50658.txt',
#  './data/dataset/data/training_data/50659.txt',
#  './data/dataset/data/training_data/50661.txt',
#  './data/dataset/data/training_data/50664.txt',
#  './data/dataset/data/training_data/50665.txt',
#  './data/dataset/data/training_data/50667.txt',
#  './data/dataset/data/training_data/50668.txt',
#  './data/dataset/data/training_data/50669.txt',
#  './data/dataset/data/training_data/50671.txt',
#  './data/dataset/data/training_data/50673.txt',
#  './data/dataset/data/training_data/50676.txt',
#  './data/dataset/data/training_data/50677.txt',
#  './data/dataset/data/training_data/50678.txt',
#  './data/dataset/data/training_data/50680.txt',
#  './data/dataset/data/training_data/50685.txt',
#  './data/dataset/data/training_data/50687.txt',
#  './data/dataset/data/training_data/50688.txt',
#  './data/dataset/data/training_data/50689.txt',
#  './data/dataset/data/training_data/50690.txt',
#  './data/dataset/data/training_data/50691.txt',
#  './data/dataset/data/training_data/50693.txt',
#  './data/dataset/data/training_data/50699.txt',
#  './data/dataset/data/training_data/50704.txt',
#  './data/dataset/data/training_data/50707.txt',
#  './data/dataset/data/training_data/50708.txt',
#  './data/dataset/data/training_data/50713.txt',
#  './data/dataset/data/training_data/50715.txt',
#  './data/dataset/data/training_data/50720.txt',
#  './data/dataset/data/training_data/50721.txt',
#  './data/dataset/data/training_data/50722.txt',
#  './data/dataset/data/training_data/50723.txt',
#  './data/dataset/data/training_data/50725.txt',
#  './data/dataset/data/training_data/50727.txt',
#  './data/dataset/data/training_data/50729.txt',
#  './data/dataset/data/training_data/50731.txt',
#  './data/dataset/data/training_data/50732.txt',
#  './data/dataset/data/training_data/50734.txt',
#  './data/dataset/data/training_data/50735.txt',
#  './data/dataset/data/training_data/50736.txt',
#  './data/dataset/data/training_data/50737.txt',
#  './data/dataset/data/training_data/50738.txt',
#  './data/dataset/data/training_data/50739.txt',
#  './data/dataset/data/training_data/50740.txt',
#  './data/dataset/data/training_data/50742.txt',
#  './data/dataset/data/training_data/50743.txt',
#  './data/dataset/data/training_data/50744.txt',
#  './data/dataset/data/training_data/50746.txt',
#  './data/dataset/data/training_data/50747.txt',
#  './data/dataset/data/training_data/50748.txt',
#  './data/dataset/data/training_data/50749.txt',
#  './data/dataset/data/training_data/50751.txt',
#  './data/dataset/data/training_data/50752.txt',
#  './data/dataset/data/training_data/50753.txt',
#  './data/dataset/data/training_data/50754.txt',
#  './data/dataset/data/training_data/50756.txt',
#  './data/dataset/data/training_data/50757.txt',
#  './data/dataset/data/training_data/50758.txt',
#  './data/dataset/data/training_data/50762.txt',
#  './data/dataset/data/training_data/50763.txt',
#  './data/dataset/data/training_data/50766.txt',
#  './data/dataset/data/training_data/50768.txt',
#  './data/dataset/data/training_data/50770.txt',
#  './data/dataset/data/training_data/50771.txt',
#  './data/dataset/data/training_data/50772.txt',
#  './data/dataset/data/training_data/50773.txt',
#  './data/dataset/data/training_data/50774.txt',
#  './data/dataset/data/training_data/50776.txt',
#  './data/dataset/data/training_data/50781.txt',
#  './data/dataset/data/training_data/50782.txt',
#  './data/dataset/data/training_data/50784.txt',
#  './data/dataset/data/training_data/50787.txt',
#  './data/dataset/data/training_data/50788.txt',
#  './data/dataset/data/training_data/50789.txt',
#  './data/dataset/data/training_data/50790.txt',
#  './data/dataset/data/training_data/50793.txt',
#  './data/dataset/data/training_data/50795.txt',
#  './data/dataset/data/training_data/50796.txt',
#  './data/dataset/data/training_data/50797.txt',
#  './data/dataset/data/training_data/50798.txt',
#  './data/dataset/data/training_data/50800.txt',
#  './data/dataset/data/training_data/50802.txt',
#  './data/dataset/data/training_data/50803.txt',
#  './data/dataset/data/training_data/50805.txt',
#  './data/dataset/data/training_data/50807.txt',
#  './data/dataset/data/training_data/50812.txt',
#  './data/dataset/data/training_data/50815.txt',
#  './data/dataset/data/training_data/50818.txt',
#  './data/dataset/data/training_data/50819.txt',
#  './data/dataset/data/training_data/50820.txt',
#  './data/dataset/data/training_data/50822.txt',
#  './data/dataset/data/training_data/50826.txt',
#  './data/dataset/data/training_data/50829.txt',
#  './data/dataset/data/training_data/51064.txt',
#  './data/dataset/data/training_data/51331.txt',
#  './data/dataset/data/training_data/55945.txt',
#  './data/dataset/data/training_data/57700.txt',
#  './data/dataset/data/training_data/57706.txt',
#  './data/dataset/data/training_data/59536.txt',
#  './data/dataset/data/training_data/61117.txt',
#  './data/dataset/data/training_data/61610.txt',
#  './data/dataset/data/training_data/63456.txt',
#  './data/dataset/data/training_data/63581.txt',
#  './data/dataset/data/training_data/64256.txt',
#  './data/dataset/data/training_data/64715.txt',
#  './data/dataset/data/training_data/68175.txt',
#  './data/dataset/data/training_data/68182.txt',
#  './data/dataset/data/training_data/68186.txt',
#  './data/dataset/data/training_data/68194.txt',
#  './data/dataset/data/training_data/68204.txt',
#  './data/dataset/data/training_data/68213.txt',
#  './data/dataset/data/training_data/68219.txt',
#  './data/dataset/data/training_data/68222.txt',
#  './data/dataset/data/training_data/68255.txt',
#  './data/dataset/data/training_data/68260.txt',
#  './data/dataset/data/training_data/68269.txt',
#  './data/dataset/data/training_data/68279.txt',
#  './data/dataset/data/training_data/68292.txt',
#  './data/dataset/data/training_data/68298.txt',
#  './data/dataset/data/training_data/68303.txt',
#  './data/dataset/data/training_data/68306.txt',
#  './data/dataset/data/training_data/68316.txt',
#  './data/dataset/data/training_data/68318.txt',
#  './data/dataset/data/training_data/68327.txt',
#  './data/dataset/data/training_data/68330.txt',
#  './data/dataset/data/training_data/68337.txt',
#  './data/dataset/data/training_data/68347.txt',
#  './data/dataset/data/training_data/68359.txt',
#  './data/dataset/data/training_data/68363.txt',
#  './data/dataset/data/training_data/68368.txt',
#  './data/dataset/data/training_data/68374.txt',
#  './data/dataset/data/training_data/68377.txt',
#  './data/dataset/data/training_data/68379.txt',
#  './data/dataset/data/training_data/68394.txt',
#  './data/dataset/data/training_data/68395.txt',
#  './data/dataset/data/training_data/68404.txt',
#  './data/dataset/data/training_data/68406.txt',
#  './data/dataset/data/training_data/68407.txt',
#  './data/dataset/data/training_data/68412.txt',
#  './data/dataset/data/training_data/68413.txt',
#  './data/dataset/data/training_data/68419.txt',
#  './data/dataset/data/training_data/68423.txt',
#  './data/dataset/data/training_data/68425.txt',
#  './data/dataset/data/training_data/68427.txt',
#  './data/dataset/data/training_data/68431.txt',
#  './data/dataset/data/training_data/68432.txt',
#  './data/dataset/data/training_data/68435.txt',
#  './data/dataset/data/training_data/68436.txt',
#  './data/dataset/data/training_data/68444.txt',
#  './data/dataset/data/training_data/68449.txt',
#  './data/dataset/data/training_data/68456.txt',
#  './data/dataset/data/training_data/68460.txt',
#  './data/dataset/data/training_data/68465.txt',
#  './data/dataset/data/training_data/68470.txt',
#  './data/dataset/data/training_data/68477.txt',
#  './data/dataset/data/training_data/68478.txt',
#  './data/dataset/data/training_data/68482.txt',
#  './data/dataset/data/training_data/68484.txt',
#  './data/dataset/data/training_data/68487.txt',
#  './data/dataset/data/training_data/68498.txt',
#  './data/dataset/data/training_data/68504.txt',
#  './data/dataset/data/training_data/68532.txt',
#  './data/dataset/data/training_data/68545.txt',
#  './data/dataset/data/training_data/68556.txt',
#  './data/dataset/data/training_data/68560.txt',
#  './data/dataset/data/training_data/68567.txt',
#  './data/dataset/data/training_data/68576.txt',
#  './data/dataset/data/training_data/68582.txt',
#  './data/dataset/data/training_data/68624.txt',
#  './data/dataset/data/training_data/68632.txt',
#  './data/dataset/data/training_data/68646.txt',
#  './data/dataset/data/training_data/68659.txt',
#  './data/dataset/data/training_data/68660.txt',
#  './data/dataset/data/training_data/68682.txt',
#  './data/dataset/data/training_data/68698.txt',
#  './data/dataset/data/training_data/68702.txt',
#  './data/dataset/data/training_data/68705.txt',
#  './data/dataset/data/training_data/68708.txt',
#  './data/dataset/data/training_data/68711.txt',
#  './data/dataset/data/training_data/68737.txt',
#  './data/dataset/data/training_data/68738.txt',
#  './data/dataset/data/training_data/68740.txt',
#  './data/dataset/data/training_data/68741.txt',
#  './data/dataset/data/training_data/68752.txt',
#  './data/dataset/data/training_data/68755.txt',
#  './data/dataset/data/training_data/68756.txt',
#  './data/dataset/data/training_data/68757.txt',
#  './data/dataset/data/training_data/68796.txt',
#  './data/dataset/data/training_data/68827.txt',
#  './data/dataset/data/training_data/68831.txt',
#  './data/dataset/data/training_data/68849.txt',
#  './data/dataset/data/training_data/68857.txt',
#  './data/dataset/data/training_data/68861.txt',
#  './data/dataset/data/training_data/68864.txt',
#  './data/dataset/data/training_data/68874.txt',
#  './data/dataset/data/training_data/68886.txt',
#  './data/dataset/data/training_data/68887.txt',
#  './data/dataset/data/training_data/68888.txt',
#  './data/dataset/data/training_data/68895.txt',
#  './data/dataset/data/training_data/68901.txt',
#  './data/dataset/data/training_data/68908.txt',
#  './data/dataset/data/training_data/68909.txt',
#  './data/dataset/data/training_data/68952.txt',
#  './data/dataset/data/training_data/69060.txt',
#  './data/dataset/data/training_data/69066.txt',
#  './data/dataset/data/training_data/69067.txt',
#  './data/dataset/data/training_data/69068.txt',
#  './data/dataset/data/training_data/69079.txt',
#  './data/dataset/data/training_data/69093.txt',
#  './data/dataset/data/training_data/69095.txt',
#  './data/dataset/data/training_data/69096.txt',
#  './data/dataset/data/training_data/69106.txt',
#  './data/dataset/data/training_data/69112.txt',
#  './data/dataset/data/training_data/69120.txt',
#  './data/dataset/data/training_data/69125.txt',
#  './data/dataset/data/training_data/69129.txt',
#  './data/dataset/data/training_data/69141.txt',
#  './data/dataset/data/training_data/69144.txt',
#  './data/dataset/data/training_data/69147.txt',
#  './data/dataset/data/training_data/69152.txt',
#  './data/dataset/data/training_data/69155.txt',
#  './data/dataset/data/training_data/69159.txt',
#  './data/dataset/data/training_data/69161.txt',
#  './data/dataset/data/training_data/69174.txt',
#  './data/dataset/data/training_data/69176.txt',
#  './data/dataset/data/training_data/69188.txt',
#  './data/dataset/data/training_data/70280.txt',
#  './data/dataset/data/training_data/72283.txt',
#  './data/dataset/data/training_data/72288.txt',
#  './data/dataset/data/training_data/73316.txt',
#  './data/dataset/data/training_data/73497.txt',
#  './data/dataset/data/training_data/74417.txt',
#  './data/dataset/data/training_data/74420.txt',
#  './data/dataset/data/training_data/75440.txt',
#  './data/dataset/data/training_data/76240.txt',
#  './data/dataset/data/training_data/76758.txt',
#  './data/dataset/data/training_data/77373.txt',
#  './data/dataset/data/training_data/78280.txt',
#  './data/dataset/data/training_data/78582.txt',
#  './data/dataset/data/training_data/78592.txt',
#  './data/dataset/data/training_data/80348.txt',
#  './data/dataset/data/training_data/81035.txt',
#  './data/dataset/data/training_data/81297.txt',
#  './data/dataset/data/training_data/81501.txt',
#  './data/dataset/data/training_data/81638.txt',
#  './data/dataset/data/training_data/82275.txt',
#  './data/dataset/data/training_data/83094.txt',
#  './data/dataset/data/training_data/84687.txt',
#  './data/dataset/data/training_data/84688.txt',
#  './data/dataset/data/training_data/84689.txt',
#  './data/dataset/data/training_data/84690.txt',
#  './data/dataset/data/training_data/84692.txt',
#  './data/dataset/data/training_data/84693.txt',
#  './data/dataset/data/training_data/84695.txt',
#  './data/dataset/data/training_data/84696.txt',
#  './data/dataset/data/training_data/84697.txt',
#  './data/dataset/data/training_data/84699.txt',
#  './data/dataset/data/training_data/84702.txt',
#  './data/dataset/data/training_data/84704.txt',
#  './data/dataset/data/training_data/84706.txt',
#  './data/dataset/data/training_data/84708.txt',
#  './data/dataset/data/training_data/84709.txt',
#  './data/dataset/data/training_data/84710.txt',
#  './data/dataset/data/training_data/84711.txt',
#  './data/dataset/data/training_data/84713.txt',
#  './data/dataset/data/training_data/84714.txt',
#  './data/dataset/data/training_data/84716.txt',
#  './data/dataset/data/training_data/84718.txt',
#  './data/dataset/data/training_data/84720.txt',
#  './data/dataset/data/training_data/84721.txt',
#  './data/dataset/data/training_data/84724.txt',
#  './data/dataset/data/training_data/84725.txt',
#  './data/dataset/data/training_data/84727.txt',
#  './data/dataset/data/training_data/84730.txt',
#  './data/dataset/data/training_data/84731.txt',
#  './data/dataset/data/training_data/84732.txt',
#  './data/dataset/data/training_data/84733.txt',
#  './data/dataset/data/training_data/84734.txt',
#  './data/dataset/data/training_data/84735.txt',
#  './data/dataset/data/training_data/84736.txt',
#  './data/dataset/data/training_data/84738.txt',
#  './data/dataset/data/training_data/84740.txt',
#  './data/dataset/data/training_data/84742.txt',
#  './data/dataset/data/training_data/84743.txt',
#  './data/dataset/data/training_data/84746.txt',
#  './data/dataset/data/training_data/84747.txt',
#  './data/dataset/data/training_data/84749.txt',
#  './data/dataset/data/training_data/84750.txt',
#  './data/dataset/data/training_data/84751.txt',
#  './data/dataset/data/training_data/84753.txt',
#  './data/dataset/data/training_data/84754.txt',
#  './data/dataset/data/training_data/84755.txt',
#  './data/dataset/data/training_data/84758.txt',
#  './data/dataset/data/training_data/84760.txt',
#  './data/dataset/data/training_data/84761.txt',
#  './data/dataset/data/training_data/84762.txt',
#  './data/dataset/data/training_data/84764.txt',
#  './data/dataset/data/training_data/84765.txt',
#  './data/dataset/data/training_data/84768.txt',
#  './data/dataset/data/training_data/84769.txt',
#  './data/dataset/data/training_data/84775.txt',
#  './data/dataset/data/training_data/84776.txt',
#  './data/dataset/data/training_data/84778.txt',
#  './data/dataset/data/training_data/84779.txt',
#  './data/dataset/data/training_data/84780.txt',
#  './data/dataset/data/training_data/84784.txt',
#  './data/dataset/data/training_data/84785.txt',
#  './data/dataset/data/training_data/84786.txt',
#  './data/dataset/data/training_data/84790.txt',
#  './data/dataset/data/training_data/84793.txt',
#  './data/dataset/data/training_data/84796.txt',
#  './data/dataset/data/training_data/84798.txt',
#  './data/dataset/data/training_data/84799.txt',
#  './data/dataset/data/training_data/84802.txt',
#  './data/dataset/data/training_data/84803.txt',
#  './data/dataset/data/training_data/84804.txt',
#  './data/dataset/data/training_data/84805.txt',
#  './data/dataset/data/training_data/84807.txt',
#  './data/dataset/data/training_data/84808.txt',
#  './data/dataset/data/training_data/84809.txt',
#  './data/dataset/data/training_data/84813.txt',
#  './data/dataset/data/training_data/84814.txt',
#  './data/dataset/data/training_data/84815.txt',
#  './data/dataset/data/training_data/84822.txt',
#  './data/dataset/data/training_data/84823.txt',
#  './data/dataset/data/training_data/84824.txt',
#  './data/dataset/data/training_data/84826.txt',
#  './data/dataset/data/training_data/84829.txt',
#  './data/dataset/data/training_data/84831.txt',
#  './data/dataset/data/training_data/84834.txt',
#  './data/dataset/data/training_data/84835.txt',
#  './data/dataset/data/training_data/84837.txt',
#  './data/dataset/data/training_data/84838.txt',
#  './data/dataset/data/training_data/84839.txt',
#  './data/dataset/data/training_data/84840.txt',
#  './data/dataset/data/training_data/84851.txt',
#  './data/dataset/data/training_data/84852.txt',
#  './data/dataset/data/training_data/84853.txt',
#  './data/dataset/data/training_data/84854.txt',
#  './data/dataset/data/training_data/84855.txt',
#  './data/dataset/data/training_data/84856.txt',
#  './data/dataset/data/training_data/84857.txt',
#  './data/dataset/data/training_data/84859.txt',
#  './data/dataset/data/training_data/84861.txt',
#  './data/dataset/data/training_data/84863.txt',
#  './data/dataset/data/training_data/84864.txt',
#  './data/dataset/data/training_data/84865.txt',
#  './data/dataset/data/training_data/84866.txt',
#  './data/dataset/data/training_data/84868.txt',
#  './data/dataset/data/training_data/84870.txt',
#  './data/dataset/data/training_data/84874.txt',
#  './data/dataset/data/training_data/84875.txt',
#  './data/dataset/data/training_data/84876.txt',
#  './data/dataset/data/training_data/84877.txt',
#  './data/dataset/data/training_data/84878.txt',
#  './data/dataset/data/training_data/84879.txt',
#  './data/dataset/data/training_data/84881.txt',
#  './data/dataset/data/training_data/84882.txt',
#  './data/dataset/data/training_data/84883.txt',
#  './data/dataset/data/training_data/84884.txt',
#  './data/dataset/data/training_data/84885.txt',
#  './data/dataset/data/training_data/84886.txt',
#  './data/dataset/data/training_data/84887.txt',
#  './data/dataset/data/training_data/84890.txt',
#  './data/dataset/data/training_data/84892.txt',
#  './data/dataset/data/training_data/84893.txt',
#  './data/dataset/data/training_data/84894.txt',
#  './data/dataset/data/training_data/84896.txt',
#  './data/dataset/data/training_data/84900.txt',
#  './data/dataset/data/training_data/84912.txt',
#  './data/dataset/data/training_data/84917.txt',
#  './data/dataset/data/training_data/84918.txt',
#  './data/dataset/data/training_data/84919.txt',
#  './data/dataset/data/training_data/84920.txt',
#  './data/dataset/data/training_data/84921.txt',
#  './data/dataset/data/training_data/84922.txt',
#  './data/dataset/data/training_data/84923.txt',
#  './data/dataset/data/training_data/84928.txt',
#  './data/dataset/data/training_data/84930.txt',
#  './data/dataset/data/training_data/84931.txt',
#  './data/dataset/data/training_data/84933.txt',
#  './data/dataset/data/training_data/84934.txt',
#  './data/dataset/data/training_data/84935.txt',
#  './data/dataset/data/training_data/84936.txt',
#  './data/dataset/data/training_data/84937.txt',
#  './data/dataset/data/training_data/84939.txt',
#  './data/dataset/data/training_data/84942.txt',
#  './data/dataset/data/training_data/84945.txt',
#  './data/dataset/data/training_data/84946.txt',
#  './data/dataset/data/training_data/84947.txt',
#  './data/dataset/data/training_data/84949.txt',
#  './data/dataset/data/training_data/84950.txt',
#  './data/dataset/data/training_data/84952.txt',
#  './data/dataset/data/training_data/84957.txt',
#  './data/dataset/data/training_data/84960.txt',
#  './data/dataset/data/training_data/84961.txt',
#  './data/dataset/data/training_data/84962.txt',
#  './data/dataset/data/training_data/84965.txt',
#  './data/dataset/data/training_data/84966.txt',
#  './data/dataset/data/training_data/84969.txt',
#  './data/dataset/data/training_data/84970.txt',
#  './data/dataset/data/training_data/84971.txt',
#  './data/dataset/data/training_data/84973.txt',
#  './data/dataset/data/training_data/84974.txt',
#  './data/dataset/data/training_data/84976.txt',
#  './data/dataset/data/training_data/84977.txt',
#  './data/dataset/data/training_data/84978.txt',
#  './data/dataset/data/training_data/84982.txt',
#  './data/dataset/data/training_data/84983.txt',
#  './data/dataset/data/training_data/84984.txt',
#  './data/dataset/data/training_data/84985.txt',
#  './data/dataset/data/training_data/84986.txt',
#  './data/dataset/data/training_data/84987.txt',
#  './data/dataset/data/training_data/84988.txt',
#  './data/dataset/data/training_data/84990.txt',
#  './data/dataset/data/training_data/84991.txt',
#  './data/dataset/data/training_data/84992.txt',
#  './data/dataset/data/training_data/84993.txt',
#  './data/dataset/data/training_data/84994.txt',
#  './data/dataset/data/training_data/84995.txt',
#  './data/dataset/data/training_data/84996.txt',
#  './data/dataset/data/training_data/85000.txt',
#  './data/dataset/data/training_data/85002.txt',
#  './data/dataset/data/training_data/85004.txt',
#  './data/dataset/data/training_data/85010.txt',
#  './data/dataset/data/training_data/85011.txt',
#  './data/dataset/data/training_data/85012.txt',
#  './data/dataset/data/training_data/85018.txt',
#  './data/dataset/data/training_data/85019.txt',
#  './data/dataset/data/training_data/85020.txt',
#  './data/dataset/data/training_data/85023.txt',
#  './data/dataset/data/training_data/85024.txt',
#  './data/dataset/data/training_data/85026.txt',
#  './data/dataset/data/training_data/85027.txt',
#  './data/dataset/data/training_data/85028.txt',
#  './data/dataset/data/training_data/85029.txt',
#  './data/dataset/data/training_data/85030.txt',
#  './data/dataset/data/training_data/85031.txt',
#  './data/dataset/data/training_data/85033.txt',
#  './data/dataset/data/training_data/85034.txt',
#  './data/dataset/data/training_data/85035.txt',
#  './data/dataset/data/training_data/85036.txt',
#  './data/dataset/data/training_data/85037.txt',
#  './data/dataset/data/training_data/85038.txt',
#  './data/dataset/data/training_data/85042.txt',
#  './data/dataset/data/training_data/85043.txt',
#  './data/dataset/data/training_data/85044.txt',
#  './data/dataset/data/training_data/85046.txt',
#  './data/dataset/data/training_data/85048.txt',
#  './data/dataset/data/training_data/85052.txt',
#  './data/dataset/data/training_data/85053.txt',
#  './data/dataset/data/training_data/85055.txt',
#  './data/dataset/data/training_data/85057.txt',
#  './data/dataset/data/training_data/85062.txt',
#  './data/dataset/data/training_data/85063.txt',
#  './data/dataset/data/training_data/85064.txt',
#  './data/dataset/data/training_data/85066.txt',
#  './data/dataset/data/training_data/85069.txt',
#  './data/dataset/data/training_data/85075.txt',
#  './data/dataset/data/training_data/85076.txt',
#  './data/dataset/data/training_data/85077.txt',
#  './data/dataset/data/training_data/85079.txt',
#  './data/dataset/data/training_data/85080.txt',
#  './data/dataset/data/training_data/85081.txt',
#  './data/dataset/data/training_data/85084.txt',
#  './data/dataset/data/training_data/85086.txt',
#  './data/dataset/data/training_data/85087.txt',
#  './data/dataset/data/training_data/85090.txt',
#  './data/dataset/data/training_data/85091.txt',
#  './data/dataset/data/training_data/85093.txt',
#  './data/dataset/data/training_data/85094.txt',
#  './data/dataset/data/training_data/85096.txt',
#  './data/dataset/data/training_data/85099.txt',
#  './data/dataset/data/training_data/85100.txt',
#  './data/dataset/data/training_data/85102.txt',
#  './data/dataset/data/training_data/85103.txt',
#  './data/dataset/data/training_data/85105.txt',
#  './data/dataset/data/training_data/85108.txt',
#  './data/dataset/data/training_data/85109.txt',
#  './data/dataset/data/training_data/85110.txt',
#  './data/dataset/data/training_data/85112.txt',
#  './data/dataset/data/training_data/85113.txt',
#  './data/dataset/data/training_data/85114.txt',
#  './data/dataset/data/training_data/85115.txt',
#  './data/dataset/data/training_data/85116.txt',
#  './data/dataset/data/training_data/85118.txt',
#  './data/dataset/data/training_data/85119.txt',
#  './data/dataset/data/training_data/85121.txt',
#  './data/dataset/data/training_data/85122.txt',
#  './data/dataset/data/training_data/85123.txt',
#  './data/dataset/data/training_data/85124.txt',
#  './data/dataset/data/training_data/85127.txt',
#  './data/dataset/data/training_data/85128.txt',
#  './data/dataset/data/training_data/85131.txt',
#  './data/dataset/data/training_data/85132.txt',
#  './data/dataset/data/training_data/85133.txt',
#  './data/dataset/data/training_data/85134.txt',
#  './data/dataset/data/training_data/85135.txt',
#  './data/dataset/data/training_data/85136.txt',
#  './data/dataset/data/training_data/85139.txt',
#  './data/dataset/data/training_data/85140.txt',
#  './data/dataset/data/training_data/85143.txt',
#  './data/dataset/data/training_data/85144.txt',
#  './data/dataset/data/training_data/85145.txt',
#  './data/dataset/data/training_data/85147.txt',
#  './data/dataset/data/training_data/85148.txt',
#  './data/dataset/data/training_data/85150.txt',
#  './data/dataset/data/training_data/85151.txt',
#  './data/dataset/data/training_data/85152.txt',
#  './data/dataset/data/training_data/85153.txt',
#  './data/dataset/data/training_data/85154.txt',
#  './data/dataset/data/training_data/85155.txt',
#  './data/dataset/data/training_data/85157.txt',
#  './data/dataset/data/training_data/85159.txt',
#  './data/dataset/data/training_data/85161.txt',
#  './data/dataset/data/training_data/85162.txt',
#  './data/dataset/data/training_data/85163.txt',
#  './data/dataset/data/training_data/85164.txt',
#  './data/dataset/data/training_data/85165.txt',
#  './data/dataset/data/training_data/85166.txt',
#  './data/dataset/data/training_data/85167.txt',
#  './data/dataset/data/training_data/85168.txt',
#  './data/dataset/data/training_data/85169.txt',
#  './data/dataset/data/training_data/85172.txt',
#  './data/dataset/data/training_data/85174.txt',
#  './data/dataset/data/training_data/85175.txt',
#  './data/dataset/data/training_data/85176.txt',
#  './data/dataset/data/training_data/85180.txt',
#  './data/dataset/data/training_data/85181.txt',
#  './data/dataset/data/training_data/85182.txt',
#  './data/dataset/data/training_data/85184.txt',
#  './data/dataset/data/training_data/85186.txt',
#  './data/dataset/data/training_data/85192.txt',
#  './data/dataset/data/training_data/85196.txt',
#  './data/dataset/data/training_data/85197.txt',
#  './data/dataset/data/training_data/85198.txt',
#  './data/dataset/data/training_data/85199.txt',
#  './data/dataset/data/training_data/85202.txt',
#  './data/dataset/data/training_data/85203.txt',
#  './data/dataset/data/training_data/85207.txt',
#  './data/dataset/data/training_data/85210.txt',
#  './data/dataset/data/training_data/85212.txt',
#  './data/dataset/data/training_data/85213.txt',
#  './data/dataset/data/training_data/85214.txt',
#  './data/dataset/data/training_data/85216.txt',
#  './data/dataset/data/training_data/85217.txt',
#  './data/dataset/data/training_data/85219.txt',
#  './data/dataset/data/training_data/85222.txt',
#  './data/dataset/data/training_data/85225.txt',
#  './data/dataset/data/training_data/85226.txt',
#  './data/dataset/data/training_data/85227.txt',
#  './data/dataset/data/training_data/85229.txt',
#  './data/dataset/data/training_data/85230.txt',
#  './data/dataset/data/training_data/85234.txt',
#  './data/dataset/data/training_data/85235.txt',
#  './data/dataset/data/training_data/85236.txt',
#  './data/dataset/data/training_data/85239.txt',
#  './data/dataset/data/training_data/85240.txt',
#  './data/dataset/data/training_data/85241.txt',
#  './data/dataset/data/training_data/85242.txt',
#  './data/dataset/data/training_data/85243.txt',
#  './data/dataset/data/training_data/85244.txt',
#  './data/dataset/data/training_data/85245.txt',
#  './data/dataset/data/training_data/85246.txt',
#  './data/dataset/data/training_data/85247.txt',
#  './data/dataset/data/training_data/85249.txt',
#  './data/dataset/data/training_data/85250.txt',
#  './data/dataset/data/training_data/85252.txt',
#  './data/dataset/data/training_data/85253.txt',
#  './data/dataset/data/training_data/85258.txt',
#  './data/dataset/data/training_data/85259.txt',
#  './data/dataset/data/training_data/85261.txt',
#  './data/dataset/data/training_data/85262.txt',
#  './data/dataset/data/training_data/85264.txt',
#  './data/dataset/data/training_data/85265.txt',
#  './data/dataset/data/training_data/85269.txt',
#  './data/dataset/data/training_data/85270.txt',
#  './data/dataset/data/training_data/85276.txt',
#  './data/dataset/data/training_data/85277.txt',
#  './data/dataset/data/training_data/85278.txt',
#  './data/dataset/data/training_data/85279.txt',
#  './data/dataset/data/training_data/85282.txt',
#  './data/dataset/data/training_data/85285.txt',
#  './data/dataset/data/training_data/85286.txt',
#  './data/dataset/data/training_data/85287.txt',
#  './data/dataset/data/training_data/85288.txt',
#  './data/dataset/data/training_data/85293.txt',
#  './data/dataset/data/training_data/85294.txt',
#  './data/dataset/data/training_data/85296.txt',
#  './data/dataset/data/training_data/85299.txt',
#  './data/dataset/data/training_data/85300.txt',
#  './data/dataset/data/training_data/85301.txt',
#  './data/dataset/data/training_data/85305.txt',
#  './data/dataset/data/training_data/85306.txt',
#  './data/dataset/data/training_data/85308.txt',
#  './data/dataset/data/training_data/85312.txt',
#  './data/dataset/data/training_data/85313.txt',
#  './data/dataset/data/training_data/85315.txt',
#  './data/dataset/data/training_data/85316.txt',
#  './data/dataset/data/training_data/85317.txt',
#  './data/dataset/data/training_data/85319.txt',
#  './data/dataset/data/training_data/85321.txt',
#  './data/dataset/data/training_data/85322.txt',
#  './data/dataset/data/training_data/85323.txt',
#  './data/dataset/data/training_data/85326.txt',
#  './data/dataset/data/training_data/85327.txt',
#  './data/dataset/data/training_data/85328.txt',
#  './data/dataset/data/training_data/85329.txt',
#  './data/dataset/data/training_data/85331.txt',
#  './data/dataset/data/training_data/85332.txt',
#  './data/dataset/data/training_data/85334.txt',
#  './data/dataset/data/training_data/85335.txt',
#  './data/dataset/data/training_data/85336.txt',
#  './data/dataset/data/training_data/85337.txt',
#  './data/dataset/data/training_data/85338.txt',
#  './data/dataset/data/training_data/85339.txt',
#  './data/dataset/data/training_data/85340.txt',
#  './data/dataset/data/training_data/85341.txt',
#  './data/dataset/data/training_data/85343.txt',
#  './data/dataset/data/training_data/85345.txt',
#  './data/dataset/data/training_data/85349.txt']

# %%
pat_dat = load_patient_data(patient_files[0])

# %%
get_murmur(pat_dat)
# Out:
# 'Absent'

# %%
get_outcome(pat_dat)
# Out:
# 'Abnormal'

# %%
cv_murmur = []
cv_outcome = []
cv_filename = []
for i in tqdm.tqdm(range(len(patient_files))):
    # Load the current patient data and recordings.
    current_patient_data = load_patient_data(patient_files[i])
    cv_murmur.append(get_murmur(current_patient_data))
    cv_outcome.append(get_outcome(current_patient_data))
cv_outcome = np.asarray(cv_outcome)
cv_murmur = np.asarray(cv_murmur)
current_patient_data = np.asarray(current_patient_data)
# Out:
# 100%|██████████| 942/942 [00:00<00:00, 4529.19it/s]

# %%
current_patient_data
# Out:
# '85349 3 4000\nAV 85349_AV.hea 85349_AV.wav 85349_AV.tsv\nPV 85349_PV.hea 85349_PV.wav 85349_PV.tsv\nTV 85349_TV.hea 85349_TV.wav 85349_TV.tsv\n#Age: nan\n#Sex: Female\n#Height: nan\n#Weight: nan\n#Pregnancy status: True\n#Murmur: Absent\n#Murmur locations: nan\n#Most audible location: nan\n#Systolic murmur timing: nan\n#Systolic murmur shape: nan\n#Systolic murmur grading: nan\n#Systolic murmur pitch: nan\n#Systolic murmur quality: nan\n#Diastolic murmur timing: nan\n#Diastolic murmur shape: nan\n#Diastolic murmur grading: nan\n#Diastolic murmur pitch: nan\n#Diastolic murmur quality: nan\n#Outcome: Normal\n#Campaign: CC2015\n#Additional ID: nan\n'

# %%
skf = StratifiedKFold(n_splits=5)

# %%
skf.split(cv_murmur, cv_outcome)
# Out:
# <generator object _BaseKFold.split at 0x0000013564308CF0>

# %%
for train_index, val_index in skf.split(cv_murmur, cv_outcome):
    print(np.unique(cv_murmur[train_index],return_counts=True))
    print(np.unique(cv_outcome[train_index], return_counts=True))
# Out:
# (array(['Absent', 'Present', 'Unknown'], dtype='<U7'), array([559, 137,  57], dtype=int64))
# (array(['Abnormal', 'Normal'], dtype='<U8'), array([364, 389], dtype=int64))
# (array(['Absent', 'Present', 'Unknown'], dtype='<U7'), array([547, 150,  56], dtype=int64))
# (array(['Abnormal', 'Normal'], dtype='<U8'), array([365, 388], dtype=int64))
# (array(['Absent', 'Present', 'Unknown'], dtype='<U7'), array([554, 144,  56], dtype=int64))
# (array(['Abnormal', 'Normal'], dtype='<U8'), array([365, 389], dtype=int64))
# (array(['Absent', 'Present', 'Unknown'], dtype='<U7'), array([554, 150,  50], dtype=int64))
# (array(['Abnormal', 'Normal'], dtype='<U8'), array([365, 389], dtype=int64))
# (array(['Absent', 'Present', 'Unknown'], dtype='<U7'), array([566, 135,  53], dtype=int64))
# (array(['Abnormal', 'Normal'], dtype='<U8'), array([365, 389], dtype=int64))

# %%
def get_data(patient_files, data_folder, new_frequenzy, num_murmur_classes, num_outcome_classes):
    data = []
    murmurs = list()
    outcomes = list()
    for i in tqdm.tqdm(range(len(patient_files))):
        # Load the current patient data and recordings.
        current_patient_data = load_patient_data(patient_files[i])
        current_recordings, freq = load_recordings(data_folder, current_patient_data, get_frequencies=True)
        for j in range(len(current_recordings)):
            data.append(signal.resample(current_recordings[j], int((len(current_recordings[j])/freq[j]) * new_frequenzy)))
            current_auscultation_location = current_patient_data.split('\n')[1:len(current_recordings)+1][j].split(" ")[0]
            all_murmur_locations = get_murmur_locations(current_patient_data).split("+")
            current_murmur = np.zeros(num_murmur_classes, dtype=int)
            if get_murmur(current_patient_data) == "Present":
                if current_auscultation_location in all_murmur_locations:
                    current_murmur[0] = 1
                else:
                    pass
            elif get_murmur(current_patient_data) == "Unknown":
                current_murmur[1] = 1
            elif get_murmur(current_patient_data) == "Absent":
                current_murmur[2] = 1
            murmurs.append(current_murmur)

            current_outcome = np.zeros(num_outcome_classes, dtype=int)
            outcome = get_outcome(current_patient_data)
            if outcome in outcome_classes:
                j = outcome_classes.index(outcome)
                current_outcome[j] = 1
            outcomes.append(current_outcome)
    data_padded = pad_array(data, (32256//2))
    data_padded = np.expand_dims(data_padded,2)

    murmurs = np.vstack(murmurs)
    outcomes = np.argmax(np.vstack(outcomes),axis=1)

    return data_padded, murmurs, outcomes

# %%
patient_files
# Out:
# ['./data/dataset/data/training_data/2530.txt',
#  './data/dataset/data/training_data/9979.txt',
#  './data/dataset/data/training_data/9983.txt',
#  './data/dataset/data/training_data/13918.txt',
#  './data/dataset/data/training_data/14241.txt',
#  './data/dataset/data/training_data/14998.txt',
#  './data/dataset/data/training_data/23625.txt',
#  './data/dataset/data/training_data/24160.txt',
#  './data/dataset/data/training_data/29045.txt',
#  './data/dataset/data/training_data/29378.txt',
#  './data/dataset/data/training_data/31737.txt',
#  './data/dataset/data/training_data/33151.txt',
#  './data/dataset/data/training_data/36327.txt',
#  './data/dataset/data/training_data/38337.txt',
#  './data/dataset/data/training_data/39043.txt',
#  './data/dataset/data/training_data/39403.txt',
#  './data/dataset/data/training_data/39456.txt',
#  './data/dataset/data/training_data/40058.txt',
#  './data/dataset/data/training_data/40798.txt',
#  './data/dataset/data/training_data/40840.txt',
#  './data/dataset/data/training_data/43852.txt',
#  './data/dataset/data/training_data/44514.txt',
#  './data/dataset/data/training_data/45843.txt',
#  './data/dataset/data/training_data/46065.txt',
#  './data/dataset/data/training_data/46532.txt',
#  './data/dataset/data/training_data/46579.txt',
#  './data/dataset/data/training_data/46778.txt',
#  './data/dataset/data/training_data/47002.txt',
#  './data/dataset/data/training_data/49558.txt',
#  './data/dataset/data/training_data/49561.txt',
#  './data/dataset/data/training_data/49562.txt',
#  './data/dataset/data/training_data/49568.txt',
#  './data/dataset/data/training_data/49572.txt',
#  './data/dataset/data/training_data/49574.txt',
#  './data/dataset/data/training_data/49577.txt',
#  './data/dataset/data/training_data/49585.txt',
#  './data/dataset/data/training_data/49595.txt',
#  './data/dataset/data/training_data/49598.txt',
#  './data/dataset/data/training_data/49607.txt',
#  './data/dataset/data/training_data/49610.txt',
#  './data/dataset/data/training_data/49618.txt',
#  './data/dataset/data/training_data/49622.txt',
#  './data/dataset/data/training_data/49627.txt',
#  './data/dataset/data/training_data/49628.txt',
#  './data/dataset/data/training_data/49630.txt',
#  './data/dataset/data/training_data/49631.txt',
#  './data/dataset/data/training_data/49638.txt',
#  './data/dataset/data/training_data/49641.txt',
#  './data/dataset/data/training_data/49653.txt',
#  './data/dataset/data/training_data/49659.txt',
#  './data/dataset/data/training_data/49661.txt',
#  './data/dataset/data/training_data/49669.txt',
#  './data/dataset/data/training_data/49678.txt',
#  './data/dataset/data/training_data/49683.txt',
#  './data/dataset/data/training_data/49687.txt',
#  './data/dataset/data/training_data/49691.txt',
#  './data/dataset/data/training_data/49704.txt',
#  './data/dataset/data/training_data/49712.txt',
#  './data/dataset/data/training_data/49719.txt',
#  './data/dataset/data/training_data/49729.txt',
#  './data/dataset/data/training_data/49735.txt',
#  './data/dataset/data/training_data/49745.txt',
#  './data/dataset/data/training_data/49748.txt',
#  './data/dataset/data/training_data/49751.txt',
#  './data/dataset/data/training_data/49754.txt',
#  './data/dataset/data/training_data/49761.txt',
#  './data/dataset/data/training_data/49776.txt',
#  './data/dataset/data/training_data/49808.txt',
#  './data/dataset/data/training_data/49821.txt',
#  './data/dataset/data/training_data/49823.txt',
#  './data/dataset/data/training_data/49824.txt',
#  './data/dataset/data/training_data/49829.txt',
#  './data/dataset/data/training_data/49832.txt',
#  './data/dataset/data/training_data/49838.txt',
#  './data/dataset/data/training_data/49839.txt',
#  './data/dataset/data/training_data/49842.txt',
#  './data/dataset/data/training_data/49850.txt',
#  './data/dataset/data/training_data/49853.txt',
#  './data/dataset/data/training_data/49854.txt',
#  './data/dataset/data/training_data/49873.txt',
#  './data/dataset/data/training_data/49876.txt',
#  './data/dataset/data/training_data/49896.txt',
#  './data/dataset/data/training_data/49897.txt',
#  './data/dataset/data/training_data/49900.txt',
#  './data/dataset/data/training_data/49930.txt',
#  './data/dataset/data/training_data/49931.txt',
#  './data/dataset/data/training_data/49946.txt',
#  './data/dataset/data/training_data/49952.txt',
#  './data/dataset/data/training_data/49959.txt',
#  './data/dataset/data/training_data/49960.txt',
#  './data/dataset/data/training_data/49963.txt',
#  './data/dataset/data/training_data/49966.txt',
#  './data/dataset/data/training_data/49968.txt',
#  './data/dataset/data/training_data/49969.txt',
#  './data/dataset/data/training_data/49970.txt',
#  './data/dataset/data/training_data/49974.txt',
#  './data/dataset/data/training_data/49978.txt',
#  './data/dataset/data/training_data/49979.txt',
#  './data/dataset/data/training_data/49980.txt',
#  './data/dataset/data/training_data/49983.txt',
#  './data/dataset/data/training_data/49986.txt',
#  './data/dataset/data/training_data/49987.txt',
#  './data/dataset/data/training_data/49988.txt',
#  './data/dataset/data/training_data/49989.txt',
#  './data/dataset/data/training_data/49990.txt',
#  './data/dataset/data/training_data/49993.txt',
#  './data/dataset/data/training_data/49994.txt',
#  './data/dataset/data/training_data/49995.txt',
#  './data/dataset/data/training_data/49998.txt',
#  './data/dataset/data/training_data/49999.txt',
#  './data/dataset/data/training_data/50001.txt',
#  './data/dataset/data/training_data/50004.txt',
#  './data/dataset/data/training_data/50005.txt',
#  './data/dataset/data/training_data/50006.txt',
#  './data/dataset/data/training_data/50007.txt',
#  './data/dataset/data/training_data/50008.txt',
#  './data/dataset/data/training_data/50009.txt',
#  './data/dataset/data/training_data/50012.txt',
#  './data/dataset/data/training_data/50014.txt',
#  './data/dataset/data/training_data/50015.txt',
#  './data/dataset/data/training_data/50017.txt',
#  './data/dataset/data/training_data/50018.txt',
#  './data/dataset/data/training_data/50023.txt',
#  './data/dataset/data/training_data/50026.txt',
#  './data/dataset/data/training_data/50027.txt',
#  './data/dataset/data/training_data/50029.txt',
#  './data/dataset/data/training_data/50030.txt',
#  './data/dataset/data/training_data/50032.txt',
#  './data/dataset/data/training_data/50034.txt',
#  './data/dataset/data/training_data/50037.txt',
#  './data/dataset/data/training_data/50043.txt',
#  './data/dataset/data/training_data/50047.txt',
#  './data/dataset/data/training_data/50048.txt',
#  './data/dataset/data/training_data/50049.txt',
#  './data/dataset/data/training_data/50053.txt',
#  './data/dataset/data/training_data/50054.txt',
#  './data/dataset/data/training_data/50056.txt',
#  './data/dataset/data/training_data/50057.txt',
#  './data/dataset/data/training_data/50061.txt',
#  './data/dataset/data/training_data/50066.txt',
#  './data/dataset/data/training_data/50067.txt',
#  './data/dataset/data/training_data/50070.txt',
#  './data/dataset/data/training_data/50072.txt',
#  './data/dataset/data/training_data/50074.txt',
#  './data/dataset/data/training_data/50075.txt',
#  './data/dataset/data/training_data/50076.txt',
#  './data/dataset/data/training_data/50077.txt',
#  './data/dataset/data/training_data/50078.txt',
#  './data/dataset/data/training_data/50079.txt',
#  './data/dataset/data/training_data/50080.txt',
#  './data/dataset/data/training_data/50085.txt',
#  './data/dataset/data/training_data/50086.txt',
#  './data/dataset/data/training_data/50089.txt',
#  './data/dataset/data/training_data/50092.txt',
#  './data/dataset/data/training_data/50094.txt',
#  './data/dataset/data/training_data/50096.txt',
#  './data/dataset/data/training_data/50099.txt',
#  './data/dataset/data/training_data/50100.txt',
#  './data/dataset/data/training_data/50103.txt',
#  './data/dataset/data/training_data/50104.txt',
#  './data/dataset/data/training_data/50105.txt',
#  './data/dataset/data/training_data/50109.txt',
#  './data/dataset/data/training_data/50111.txt',
#  './data/dataset/data/training_data/50113.txt',
#  './data/dataset/data/training_data/50115.txt',
#  './data/dataset/data/training_data/50116.txt',
#  './data/dataset/data/training_data/50117.txt',
#  './data/dataset/data/training_data/50118.txt',
#  './data/dataset/data/training_data/50119.txt',
#  './data/dataset/data/training_data/50121.txt',
#  './data/dataset/data/training_data/50122.txt',
#  './data/dataset/data/training_data/50123.txt',
#  './data/dataset/data/training_data/50125.txt',
#  './data/dataset/data/training_data/50126.txt',
#  './data/dataset/data/training_data/50127.txt',
#  './data/dataset/data/training_data/50128.txt',
#  './data/dataset/data/training_data/50129.txt',
#  './data/dataset/data/training_data/50133.txt',
#  './data/dataset/data/training_data/50136.txt',
#  './data/dataset/data/training_data/50137.txt',
#  './data/dataset/data/training_data/50138.txt',
#  './data/dataset/data/training_data/50141.txt',
#  './data/dataset/data/training_data/50142.txt',
#  './data/dataset/data/training_data/50143.txt',
#  './data/dataset/data/training_data/50145.txt',
#  './data/dataset/data/training_data/50146.txt',
#  './data/dataset/data/training_data/50149.txt',
#  './data/dataset/data/training_data/50150.txt',
#  './data/dataset/data/training_data/50151.txt',
#  './data/dataset/data/training_data/50152.txt',
#  './data/dataset/data/training_data/50153.txt',
#  './data/dataset/data/training_data/50155.txt',
#  './data/dataset/data/training_data/50159.txt',
#  './data/dataset/data/training_data/50160.txt',
#  './data/dataset/data/training_data/50161.txt',
#  './data/dataset/data/training_data/50164.txt',
#  './data/dataset/data/training_data/50165.txt',
#  './data/dataset/data/training_data/50166.txt',
#  './data/dataset/data/training_data/50168.txt',
#  './data/dataset/data/training_data/50174.txt',
#  './data/dataset/data/training_data/50204.txt',
#  './data/dataset/data/training_data/50206.txt',
#  './data/dataset/data/training_data/50207.txt',
#  './data/dataset/data/training_data/50209.txt',
#  './data/dataset/data/training_data/50210.txt',
#  './data/dataset/data/training_data/50213.txt',
#  './data/dataset/data/training_data/50214.txt',
#  './data/dataset/data/training_data/50216.txt',
#  './data/dataset/data/training_data/50217.txt',
#  './data/dataset/data/training_data/50218.txt',
#  './data/dataset/data/training_data/50219.txt',
#  './data/dataset/data/training_data/50220.txt',
#  './data/dataset/data/training_data/50221.txt',
#  './data/dataset/data/training_data/50222.txt',
#  './data/dataset/data/training_data/50225.txt',
#  './data/dataset/data/training_data/50228.txt',
#  './data/dataset/data/training_data/50229.txt',
#  './data/dataset/data/training_data/50230.txt',
#  './data/dataset/data/training_data/50231.txt',
#  './data/dataset/data/training_data/50233.txt',
#  './data/dataset/data/training_data/50238.txt',
#  './data/dataset/data/training_data/50239.txt',
#  './data/dataset/data/training_data/50241.txt',
#  './data/dataset/data/training_data/50244.txt',
#  './data/dataset/data/training_data/50247.txt',
#  './data/dataset/data/training_data/50248.txt',
#  './data/dataset/data/training_data/50249.txt',
#  './data/dataset/data/training_data/50250.txt',
#  './data/dataset/data/training_data/50251.txt',
#  './data/dataset/data/training_data/50254.txt',
#  './data/dataset/data/training_data/50255.txt',
#  './data/dataset/data/training_data/50256.txt',
#  './data/dataset/data/training_data/50258.txt',
#  './data/dataset/data/training_data/50260.txt',
#  './data/dataset/data/training_data/50261.txt',
#  './data/dataset/data/training_data/50263.txt',
#  './data/dataset/data/training_data/50264.txt',
#  './data/dataset/data/training_data/50271.txt',
#  './data/dataset/data/training_data/50272.txt',
#  './data/dataset/data/training_data/50273.txt',
#  './data/dataset/data/training_data/50275.txt',
#  './data/dataset/data/training_data/50276.txt',
#  './data/dataset/data/training_data/50277.txt',
#  './data/dataset/data/training_data/50278.txt',
#  './data/dataset/data/training_data/50280.txt',
#  './data/dataset/data/training_data/50281.txt',
#  './data/dataset/data/training_data/50284.txt',
#  './data/dataset/data/training_data/50285.txt',
#  './data/dataset/data/training_data/50289.txt',
#  './data/dataset/data/training_data/50291.txt',
#  './data/dataset/data/training_data/50295.txt',
#  './data/dataset/data/training_data/50296.txt',
#  './data/dataset/data/training_data/50297.txt',
#  './data/dataset/data/training_data/50298.txt',
#  './data/dataset/data/training_data/50299.txt',
#  './data/dataset/data/training_data/50300.txt',
#  './data/dataset/data/training_data/50303.txt',
#  './data/dataset/data/training_data/50304.txt',
#  './data/dataset/data/training_data/50306.txt',
#  './data/dataset/data/training_data/50311.txt',
#  './data/dataset/data/training_data/50312.txt',
#  './data/dataset/data/training_data/50314.txt',
#  './data/dataset/data/training_data/50316.txt',
#  './data/dataset/data/training_data/50317.txt',
#  './data/dataset/data/training_data/50318.txt',
#  './data/dataset/data/training_data/50319.txt',
#  './data/dataset/data/training_data/50321.txt',
#  './data/dataset/data/training_data/50323.txt',
#  './data/dataset/data/training_data/50325.txt',
#  './data/dataset/data/training_data/50326.txt',
#  './data/dataset/data/training_data/50327.txt',
#  './data/dataset/data/training_data/50330.txt',
#  './data/dataset/data/training_data/50331.txt',
#  './data/dataset/data/training_data/50332.txt',
#  './data/dataset/data/training_data/50334.txt',
#  './data/dataset/data/training_data/50335.txt',
#  './data/dataset/data/training_data/50336.txt',
#  './data/dataset/data/training_data/50337.txt',
#  './data/dataset/data/training_data/50339.txt',
#  './data/dataset/data/training_data/50341.txt',
#  './data/dataset/data/training_data/50342.txt',
#  './data/dataset/data/training_data/50343.txt',
#  './data/dataset/data/training_data/50345.txt',
#  './data/dataset/data/training_data/50348.txt',
#  './data/dataset/data/training_data/50349.txt',
#  './data/dataset/data/training_data/50350.txt',
#  './data/dataset/data/training_data/50352.txt',
#  './data/dataset/data/training_data/50354.txt',
#  './data/dataset/data/training_data/50359.txt',
#  './data/dataset/data/training_data/50375.txt',
#  './data/dataset/data/training_data/50379.txt',
#  './data/dataset/data/training_data/50384.txt',
#  './data/dataset/data/training_data/50385.txt',
#  './data/dataset/data/training_data/50386.txt',
#  './data/dataset/data/training_data/50388.txt',
#  './data/dataset/data/training_data/50391.txt',
#  './data/dataset/data/training_data/50393.txt',
#  './data/dataset/data/training_data/50619.txt',
#  './data/dataset/data/training_data/50620.txt',
#  './data/dataset/data/training_data/50621.txt',
#  './data/dataset/data/training_data/50624.txt',
#  './data/dataset/data/training_data/50625.txt',
#  './data/dataset/data/training_data/50626.txt',
#  './data/dataset/data/training_data/50628.txt',
#  './data/dataset/data/training_data/50629.txt',
#  './data/dataset/data/training_data/50631.txt',
#  './data/dataset/data/training_data/50635.txt',
#  './data/dataset/data/training_data/50636.txt',
#  './data/dataset/data/training_data/50639.txt',
#  './data/dataset/data/training_data/50640.txt',
#  './data/dataset/data/training_data/50641.txt',
#  './data/dataset/data/training_data/50643.txt',
#  './data/dataset/data/training_data/50644.txt',
#  './data/dataset/data/training_data/50645.txt',
#  './data/dataset/data/training_data/50646.txt',
#  './data/dataset/data/training_data/50647.txt',
#  './data/dataset/data/training_data/50649.txt',
#  './data/dataset/data/training_data/50652.txt',
#  './data/dataset/data/training_data/50654.txt',
#  './data/dataset/data/training_data/50655.txt',
#  './data/dataset/data/training_data/50656.txt',
#  './data/dataset/data/training_data/50657.txt',
#  './data/dataset/data/training_data/50658.txt',
#  './data/dataset/data/training_data/50659.txt',
#  './data/dataset/data/training_data/50661.txt',
#  './data/dataset/data/training_data/50664.txt',
#  './data/dataset/data/training_data/50665.txt',
#  './data/dataset/data/training_data/50667.txt',
#  './data/dataset/data/training_data/50668.txt',
#  './data/dataset/data/training_data/50669.txt',
#  './data/dataset/data/training_data/50671.txt',
#  './data/dataset/data/training_data/50673.txt',
#  './data/dataset/data/training_data/50676.txt',
#  './data/dataset/data/training_data/50677.txt',
#  './data/dataset/data/training_data/50678.txt',
#  './data/dataset/data/training_data/50680.txt',
#  './data/dataset/data/training_data/50685.txt',
#  './data/dataset/data/training_data/50687.txt',
#  './data/dataset/data/training_data/50688.txt',
#  './data/dataset/data/training_data/50689.txt',
#  './data/dataset/data/training_data/50690.txt',
#  './data/dataset/data/training_data/50691.txt',
#  './data/dataset/data/training_data/50693.txt',
#  './data/dataset/data/training_data/50699.txt',
#  './data/dataset/data/training_data/50704.txt',
#  './data/dataset/data/training_data/50707.txt',
#  './data/dataset/data/training_data/50708.txt',
#  './data/dataset/data/training_data/50713.txt',
#  './data/dataset/data/training_data/50715.txt',
#  './data/dataset/data/training_data/50720.txt',
#  './data/dataset/data/training_data/50721.txt',
#  './data/dataset/data/training_data/50722.txt',
#  './data/dataset/data/training_data/50723.txt',
#  './data/dataset/data/training_data/50725.txt',
#  './data/dataset/data/training_data/50727.txt',
#  './data/dataset/data/training_data/50729.txt',
#  './data/dataset/data/training_data/50731.txt',
#  './data/dataset/data/training_data/50732.txt',
#  './data/dataset/data/training_data/50734.txt',
#  './data/dataset/data/training_data/50735.txt',
#  './data/dataset/data/training_data/50736.txt',
#  './data/dataset/data/training_data/50737.txt',
#  './data/dataset/data/training_data/50738.txt',
#  './data/dataset/data/training_data/50739.txt',
#  './data/dataset/data/training_data/50740.txt',
#  './data/dataset/data/training_data/50742.txt',
#  './data/dataset/data/training_data/50743.txt',
#  './data/dataset/data/training_data/50744.txt',
#  './data/dataset/data/training_data/50746.txt',
#  './data/dataset/data/training_data/50747.txt',
#  './data/dataset/data/training_data/50748.txt',
#  './data/dataset/data/training_data/50749.txt',
#  './data/dataset/data/training_data/50751.txt',
#  './data/dataset/data/training_data/50752.txt',
#  './data/dataset/data/training_data/50753.txt',
#  './data/dataset/data/training_data/50754.txt',
#  './data/dataset/data/training_data/50756.txt',
#  './data/dataset/data/training_data/50757.txt',
#  './data/dataset/data/training_data/50758.txt',
#  './data/dataset/data/training_data/50762.txt',
#  './data/dataset/data/training_data/50763.txt',
#  './data/dataset/data/training_data/50766.txt',
#  './data/dataset/data/training_data/50768.txt',
#  './data/dataset/data/training_data/50770.txt',
#  './data/dataset/data/training_data/50771.txt',
#  './data/dataset/data/training_data/50772.txt',
#  './data/dataset/data/training_data/50773.txt',
#  './data/dataset/data/training_data/50774.txt',
#  './data/dataset/data/training_data/50776.txt',
#  './data/dataset/data/training_data/50781.txt',
#  './data/dataset/data/training_data/50782.txt',
#  './data/dataset/data/training_data/50784.txt',
#  './data/dataset/data/training_data/50787.txt',
#  './data/dataset/data/training_data/50788.txt',
#  './data/dataset/data/training_data/50789.txt',
#  './data/dataset/data/training_data/50790.txt',
#  './data/dataset/data/training_data/50793.txt',
#  './data/dataset/data/training_data/50795.txt',
#  './data/dataset/data/training_data/50796.txt',
#  './data/dataset/data/training_data/50797.txt',
#  './data/dataset/data/training_data/50798.txt',
#  './data/dataset/data/training_data/50800.txt',
#  './data/dataset/data/training_data/50802.txt',
#  './data/dataset/data/training_data/50803.txt',
#  './data/dataset/data/training_data/50805.txt',
#  './data/dataset/data/training_data/50807.txt',
#  './data/dataset/data/training_data/50812.txt',
#  './data/dataset/data/training_data/50815.txt',
#  './data/dataset/data/training_data/50818.txt',
#  './data/dataset/data/training_data/50819.txt',
#  './data/dataset/data/training_data/50820.txt',
#  './data/dataset/data/training_data/50822.txt',
#  './data/dataset/data/training_data/50826.txt',
#  './data/dataset/data/training_data/50829.txt',
#  './data/dataset/data/training_data/51064.txt',
#  './data/dataset/data/training_data/51331.txt',
#  './data/dataset/data/training_data/55945.txt',
#  './data/dataset/data/training_data/57700.txt',
#  './data/dataset/data/training_data/57706.txt',
#  './data/dataset/data/training_data/59536.txt',
#  './data/dataset/data/training_data/61117.txt',
#  './data/dataset/data/training_data/61610.txt',
#  './data/dataset/data/training_data/63456.txt',
#  './data/dataset/data/training_data/63581.txt',
#  './data/dataset/data/training_data/64256.txt',
#  './data/dataset/data/training_data/64715.txt',
#  './data/dataset/data/training_data/68175.txt',
#  './data/dataset/data/training_data/68182.txt',
#  './data/dataset/data/training_data/68186.txt',
#  './data/dataset/data/training_data/68194.txt',
#  './data/dataset/data/training_data/68204.txt',
#  './data/dataset/data/training_data/68213.txt',
#  './data/dataset/data/training_data/68219.txt',
#  './data/dataset/data/training_data/68222.txt',
#  './data/dataset/data/training_data/68255.txt',
#  './data/dataset/data/training_data/68260.txt',
#  './data/dataset/data/training_data/68269.txt',
#  './data/dataset/data/training_data/68279.txt',
#  './data/dataset/data/training_data/68292.txt',
#  './data/dataset/data/training_data/68298.txt',
#  './data/dataset/data/training_data/68303.txt',
#  './data/dataset/data/training_data/68306.txt',
#  './data/dataset/data/training_data/68316.txt',
#  './data/dataset/data/training_data/68318.txt',
#  './data/dataset/data/training_data/68327.txt',
#  './data/dataset/data/training_data/68330.txt',
#  './data/dataset/data/training_data/68337.txt',
#  './data/dataset/data/training_data/68347.txt',
#  './data/dataset/data/training_data/68359.txt',
#  './data/dataset/data/training_data/68363.txt',
#  './data/dataset/data/training_data/68368.txt',
#  './data/dataset/data/training_data/68374.txt',
#  './data/dataset/data/training_data/68377.txt',
#  './data/dataset/data/training_data/68379.txt',
#  './data/dataset/data/training_data/68394.txt',
#  './data/dataset/data/training_data/68395.txt',
#  './data/dataset/data/training_data/68404.txt',
#  './data/dataset/data/training_data/68406.txt',
#  './data/dataset/data/training_data/68407.txt',
#  './data/dataset/data/training_data/68412.txt',
#  './data/dataset/data/training_data/68413.txt',
#  './data/dataset/data/training_data/68419.txt',
#  './data/dataset/data/training_data/68423.txt',
#  './data/dataset/data/training_data/68425.txt',
#  './data/dataset/data/training_data/68427.txt',
#  './data/dataset/data/training_data/68431.txt',
#  './data/dataset/data/training_data/68432.txt',
#  './data/dataset/data/training_data/68435.txt',
#  './data/dataset/data/training_data/68436.txt',
#  './data/dataset/data/training_data/68444.txt',
#  './data/dataset/data/training_data/68449.txt',
#  './data/dataset/data/training_data/68456.txt',
#  './data/dataset/data/training_data/68460.txt',
#  './data/dataset/data/training_data/68465.txt',
#  './data/dataset/data/training_data/68470.txt',
#  './data/dataset/data/training_data/68477.txt',
#  './data/dataset/data/training_data/68478.txt',
#  './data/dataset/data/training_data/68482.txt',
#  './data/dataset/data/training_data/68484.txt',
#  './data/dataset/data/training_data/68487.txt',
#  './data/dataset/data/training_data/68498.txt',
#  './data/dataset/data/training_data/68504.txt',
#  './data/dataset/data/training_data/68532.txt',
#  './data/dataset/data/training_data/68545.txt',
#  './data/dataset/data/training_data/68556.txt',
#  './data/dataset/data/training_data/68560.txt',
#  './data/dataset/data/training_data/68567.txt',
#  './data/dataset/data/training_data/68576.txt',
#  './data/dataset/data/training_data/68582.txt',
#  './data/dataset/data/training_data/68624.txt',
#  './data/dataset/data/training_data/68632.txt',
#  './data/dataset/data/training_data/68646.txt',
#  './data/dataset/data/training_data/68659.txt',
#  './data/dataset/data/training_data/68660.txt',
#  './data/dataset/data/training_data/68682.txt',
#  './data/dataset/data/training_data/68698.txt',
#  './data/dataset/data/training_data/68702.txt',
#  './data/dataset/data/training_data/68705.txt',
#  './data/dataset/data/training_data/68708.txt',
#  './data/dataset/data/training_data/68711.txt',
#  './data/dataset/data/training_data/68737.txt',
#  './data/dataset/data/training_data/68738.txt',
#  './data/dataset/data/training_data/68740.txt',
#  './data/dataset/data/training_data/68741.txt',
#  './data/dataset/data/training_data/68752.txt',
#  './data/dataset/data/training_data/68755.txt',
#  './data/dataset/data/training_data/68756.txt',
#  './data/dataset/data/training_data/68757.txt',
#  './data/dataset/data/training_data/68796.txt',
#  './data/dataset/data/training_data/68827.txt',
#  './data/dataset/data/training_data/68831.txt',
#  './data/dataset/data/training_data/68849.txt',
#  './data/dataset/data/training_data/68857.txt',
#  './data/dataset/data/training_data/68861.txt',
#  './data/dataset/data/training_data/68864.txt',
#  './data/dataset/data/training_data/68874.txt',
#  './data/dataset/data/training_data/68886.txt',
#  './data/dataset/data/training_data/68887.txt',
#  './data/dataset/data/training_data/68888.txt',
#  './data/dataset/data/training_data/68895.txt',
#  './data/dataset/data/training_data/68901.txt',
#  './data/dataset/data/training_data/68908.txt',
#  './data/dataset/data/training_data/68909.txt',
#  './data/dataset/data/training_data/68952.txt',
#  './data/dataset/data/training_data/69060.txt',
#  './data/dataset/data/training_data/69066.txt',
#  './data/dataset/data/training_data/69067.txt',
#  './data/dataset/data/training_data/69068.txt',
#  './data/dataset/data/training_data/69079.txt',
#  './data/dataset/data/training_data/69093.txt',
#  './data/dataset/data/training_data/69095.txt',
#  './data/dataset/data/training_data/69096.txt',
#  './data/dataset/data/training_data/69106.txt',
#  './data/dataset/data/training_data/69112.txt',
#  './data/dataset/data/training_data/69120.txt',
#  './data/dataset/data/training_data/69125.txt',
#  './data/dataset/data/training_data/69129.txt',
#  './data/dataset/data/training_data/69141.txt',
#  './data/dataset/data/training_data/69144.txt',
#  './data/dataset/data/training_data/69147.txt',
#  './data/dataset/data/training_data/69152.txt',
#  './data/dataset/data/training_data/69155.txt',
#  './data/dataset/data/training_data/69159.txt',
#  './data/dataset/data/training_data/69161.txt',
#  './data/dataset/data/training_data/69174.txt',
#  './data/dataset/data/training_data/69176.txt',
#  './data/dataset/data/training_data/69188.txt',
#  './data/dataset/data/training_data/70280.txt',
#  './data/dataset/data/training_data/72283.txt',
#  './data/dataset/data/training_data/72288.txt',
#  './data/dataset/data/training_data/73316.txt',
#  './data/dataset/data/training_data/73497.txt',
#  './data/dataset/data/training_data/74417.txt',
#  './data/dataset/data/training_data/74420.txt',
#  './data/dataset/data/training_data/75440.txt',
#  './data/dataset/data/training_data/76240.txt',
#  './data/dataset/data/training_data/76758.txt',
#  './data/dataset/data/training_data/77373.txt',
#  './data/dataset/data/training_data/78280.txt',
#  './data/dataset/data/training_data/78582.txt',
#  './data/dataset/data/training_data/78592.txt',
#  './data/dataset/data/training_data/80348.txt',
#  './data/dataset/data/training_data/81035.txt',
#  './data/dataset/data/training_data/81297.txt',
#  './data/dataset/data/training_data/81501.txt',
#  './data/dataset/data/training_data/81638.txt',
#  './data/dataset/data/training_data/82275.txt',
#  './data/dataset/data/training_data/83094.txt',
#  './data/dataset/data/training_data/84687.txt',
#  './data/dataset/data/training_data/84688.txt',
#  './data/dataset/data/training_data/84689.txt',
#  './data/dataset/data/training_data/84690.txt',
#  './data/dataset/data/training_data/84692.txt',
#  './data/dataset/data/training_data/84693.txt',
#  './data/dataset/data/training_data/84695.txt',
#  './data/dataset/data/training_data/84696.txt',
#  './data/dataset/data/training_data/84697.txt',
#  './data/dataset/data/training_data/84699.txt',
#  './data/dataset/data/training_data/84702.txt',
#  './data/dataset/data/training_data/84704.txt',
#  './data/dataset/data/training_data/84706.txt',
#  './data/dataset/data/training_data/84708.txt',
#  './data/dataset/data/training_data/84709.txt',
#  './data/dataset/data/training_data/84710.txt',
#  './data/dataset/data/training_data/84711.txt',
#  './data/dataset/data/training_data/84713.txt',
#  './data/dataset/data/training_data/84714.txt',
#  './data/dataset/data/training_data/84716.txt',
#  './data/dataset/data/training_data/84718.txt',
#  './data/dataset/data/training_data/84720.txt',
#  './data/dataset/data/training_data/84721.txt',
#  './data/dataset/data/training_data/84724.txt',
#  './data/dataset/data/training_data/84725.txt',
#  './data/dataset/data/training_data/84727.txt',
#  './data/dataset/data/training_data/84730.txt',
#  './data/dataset/data/training_data/84731.txt',
#  './data/dataset/data/training_data/84732.txt',
#  './data/dataset/data/training_data/84733.txt',
#  './data/dataset/data/training_data/84734.txt',
#  './data/dataset/data/training_data/84735.txt',
#  './data/dataset/data/training_data/84736.txt',
#  './data/dataset/data/training_data/84738.txt',
#  './data/dataset/data/training_data/84740.txt',
#  './data/dataset/data/training_data/84742.txt',
#  './data/dataset/data/training_data/84743.txt',
#  './data/dataset/data/training_data/84746.txt',
#  './data/dataset/data/training_data/84747.txt',
#  './data/dataset/data/training_data/84749.txt',
#  './data/dataset/data/training_data/84750.txt',
#  './data/dataset/data/training_data/84751.txt',
#  './data/dataset/data/training_data/84753.txt',
#  './data/dataset/data/training_data/84754.txt',
#  './data/dataset/data/training_data/84755.txt',
#  './data/dataset/data/training_data/84758.txt',
#  './data/dataset/data/training_data/84760.txt',
#  './data/dataset/data/training_data/84761.txt',
#  './data/dataset/data/training_data/84762.txt',
#  './data/dataset/data/training_data/84764.txt',
#  './data/dataset/data/training_data/84765.txt',
#  './data/dataset/data/training_data/84768.txt',
#  './data/dataset/data/training_data/84769.txt',
#  './data/dataset/data/training_data/84775.txt',
#  './data/dataset/data/training_data/84776.txt',
#  './data/dataset/data/training_data/84778.txt',
#  './data/dataset/data/training_data/84779.txt',
#  './data/dataset/data/training_data/84780.txt',
#  './data/dataset/data/training_data/84784.txt',
#  './data/dataset/data/training_data/84785.txt',
#  './data/dataset/data/training_data/84786.txt',
#  './data/dataset/data/training_data/84790.txt',
#  './data/dataset/data/training_data/84793.txt',
#  './data/dataset/data/training_data/84796.txt',
#  './data/dataset/data/training_data/84798.txt',
#  './data/dataset/data/training_data/84799.txt',
#  './data/dataset/data/training_data/84802.txt',
#  './data/dataset/data/training_data/84803.txt',
#  './data/dataset/data/training_data/84804.txt',
#  './data/dataset/data/training_data/84805.txt',
#  './data/dataset/data/training_data/84807.txt',
#  './data/dataset/data/training_data/84808.txt',
#  './data/dataset/data/training_data/84809.txt',
#  './data/dataset/data/training_data/84813.txt',
#  './data/dataset/data/training_data/84814.txt',
#  './data/dataset/data/training_data/84815.txt',
#  './data/dataset/data/training_data/84822.txt',
#  './data/dataset/data/training_data/84823.txt',
#  './data/dataset/data/training_data/84824.txt',
#  './data/dataset/data/training_data/84826.txt',
#  './data/dataset/data/training_data/84829.txt',
#  './data/dataset/data/training_data/84831.txt',
#  './data/dataset/data/training_data/84834.txt',
#  './data/dataset/data/training_data/84835.txt',
#  './data/dataset/data/training_data/84837.txt',
#  './data/dataset/data/training_data/84838.txt',
#  './data/dataset/data/training_data/84839.txt',
#  './data/dataset/data/training_data/84840.txt',
#  './data/dataset/data/training_data/84851.txt',
#  './data/dataset/data/training_data/84852.txt',
#  './data/dataset/data/training_data/84853.txt',
#  './data/dataset/data/training_data/84854.txt',
#  './data/dataset/data/training_data/84855.txt',
#  './data/dataset/data/training_data/84856.txt',
#  './data/dataset/data/training_data/84857.txt',
#  './data/dataset/data/training_data/84859.txt',
#  './data/dataset/data/training_data/84861.txt',
#  './data/dataset/data/training_data/84863.txt',
#  './data/dataset/data/training_data/84864.txt',
#  './data/dataset/data/training_data/84865.txt',
#  './data/dataset/data/training_data/84866.txt',
#  './data/dataset/data/training_data/84868.txt',
#  './data/dataset/data/training_data/84870.txt',
#  './data/dataset/data/training_data/84874.txt',
#  './data/dataset/data/training_data/84875.txt',
#  './data/dataset/data/training_data/84876.txt',
#  './data/dataset/data/training_data/84877.txt',
#  './data/dataset/data/training_data/84878.txt',
#  './data/dataset/data/training_data/84879.txt',
#  './data/dataset/data/training_data/84881.txt',
#  './data/dataset/data/training_data/84882.txt',
#  './data/dataset/data/training_data/84883.txt',
#  './data/dataset/data/training_data/84884.txt',
#  './data/dataset/data/training_data/84885.txt',
#  './data/dataset/data/training_data/84886.txt',
#  './data/dataset/data/training_data/84887.txt',
#  './data/dataset/data/training_data/84890.txt',
#  './data/dataset/data/training_data/84892.txt',
#  './data/dataset/data/training_data/84893.txt',
#  './data/dataset/data/training_data/84894.txt',
#  './data/dataset/data/training_data/84896.txt',
#  './data/dataset/data/training_data/84900.txt',
#  './data/dataset/data/training_data/84912.txt',
#  './data/dataset/data/training_data/84917.txt',
#  './data/dataset/data/training_data/84918.txt',
#  './data/dataset/data/training_data/84919.txt',
#  './data/dataset/data/training_data/84920.txt',
#  './data/dataset/data/training_data/84921.txt',
#  './data/dataset/data/training_data/84922.txt',
#  './data/dataset/data/training_data/84923.txt',
#  './data/dataset/data/training_data/84928.txt',
#  './data/dataset/data/training_data/84930.txt',
#  './data/dataset/data/training_data/84931.txt',
#  './data/dataset/data/training_data/84933.txt',
#  './data/dataset/data/training_data/84934.txt',
#  './data/dataset/data/training_data/84935.txt',
#  './data/dataset/data/training_data/84936.txt',
#  './data/dataset/data/training_data/84937.txt',
#  './data/dataset/data/training_data/84939.txt',
#  './data/dataset/data/training_data/84942.txt',
#  './data/dataset/data/training_data/84945.txt',
#  './data/dataset/data/training_data/84946.txt',
#  './data/dataset/data/training_data/84947.txt',
#  './data/dataset/data/training_data/84949.txt',
#  './data/dataset/data/training_data/84950.txt',
#  './data/dataset/data/training_data/84952.txt',
#  './data/dataset/data/training_data/84957.txt',
#  './data/dataset/data/training_data/84960.txt',
#  './data/dataset/data/training_data/84961.txt',
#  './data/dataset/data/training_data/84962.txt',
#  './data/dataset/data/training_data/84965.txt',
#  './data/dataset/data/training_data/84966.txt',
#  './data/dataset/data/training_data/84969.txt',
#  './data/dataset/data/training_data/84970.txt',
#  './data/dataset/data/training_data/84971.txt',
#  './data/dataset/data/training_data/84973.txt',
#  './data/dataset/data/training_data/84974.txt',
#  './data/dataset/data/training_data/84976.txt',
#  './data/dataset/data/training_data/84977.txt',
#  './data/dataset/data/training_data/84978.txt',
#  './data/dataset/data/training_data/84982.txt',
#  './data/dataset/data/training_data/84983.txt',
#  './data/dataset/data/training_data/84984.txt',
#  './data/dataset/data/training_data/84985.txt',
#  './data/dataset/data/training_data/84986.txt',
#  './data/dataset/data/training_data/84987.txt',
#  './data/dataset/data/training_data/84988.txt',
#  './data/dataset/data/training_data/84990.txt',
#  './data/dataset/data/training_data/84991.txt',
#  './data/dataset/data/training_data/84992.txt',
#  './data/dataset/data/training_data/84993.txt',
#  './data/dataset/data/training_data/84994.txt',
#  './data/dataset/data/training_data/84995.txt',
#  './data/dataset/data/training_data/84996.txt',
#  './data/dataset/data/training_data/85000.txt',
#  './data/dataset/data/training_data/85002.txt',
#  './data/dataset/data/training_data/85004.txt',
#  './data/dataset/data/training_data/85010.txt',
#  './data/dataset/data/training_data/85011.txt',
#  './data/dataset/data/training_data/85012.txt',
#  './data/dataset/data/training_data/85018.txt',
#  './data/dataset/data/training_data/85019.txt',
#  './data/dataset/data/training_data/85020.txt',
#  './data/dataset/data/training_data/85023.txt',
#  './data/dataset/data/training_data/85024.txt',
#  './data/dataset/data/training_data/85026.txt',
#  './data/dataset/data/training_data/85027.txt',
#  './data/dataset/data/training_data/85028.txt',
#  './data/dataset/data/training_data/85029.txt',
#  './data/dataset/data/training_data/85030.txt',
#  './data/dataset/data/training_data/85031.txt',
#  './data/dataset/data/training_data/85033.txt',
#  './data/dataset/data/training_data/85034.txt',
#  './data/dataset/data/training_data/85035.txt',
#  './data/dataset/data/training_data/85036.txt',
#  './data/dataset/data/training_data/85037.txt',
#  './data/dataset/data/training_data/85038.txt',
#  './data/dataset/data/training_data/85042.txt',
#  './data/dataset/data/training_data/85043.txt',
#  './data/dataset/data/training_data/85044.txt',
#  './data/dataset/data/training_data/85046.txt',
#  './data/dataset/data/training_data/85048.txt',
#  './data/dataset/data/training_data/85052.txt',
#  './data/dataset/data/training_data/85053.txt',
#  './data/dataset/data/training_data/85055.txt',
#  './data/dataset/data/training_data/85057.txt',
#  './data/dataset/data/training_data/85062.txt',
#  './data/dataset/data/training_data/85063.txt',
#  './data/dataset/data/training_data/85064.txt',
#  './data/dataset/data/training_data/85066.txt',
#  './data/dataset/data/training_data/85069.txt',
#  './data/dataset/data/training_data/85075.txt',
#  './data/dataset/data/training_data/85076.txt',
#  './data/dataset/data/training_data/85077.txt',
#  './data/dataset/data/training_data/85079.txt',
#  './data/dataset/data/training_data/85080.txt',
#  './data/dataset/data/training_data/85081.txt',
#  './data/dataset/data/training_data/85084.txt',
#  './data/dataset/data/training_data/85086.txt',
#  './data/dataset/data/training_data/85087.txt',
#  './data/dataset/data/training_data/85090.txt',
#  './data/dataset/data/training_data/85091.txt',
#  './data/dataset/data/training_data/85093.txt',
#  './data/dataset/data/training_data/85094.txt',
#  './data/dataset/data/training_data/85096.txt',
#  './data/dataset/data/training_data/85099.txt',
#  './data/dataset/data/training_data/85100.txt',
#  './data/dataset/data/training_data/85102.txt',
#  './data/dataset/data/training_data/85103.txt',
#  './data/dataset/data/training_data/85105.txt',
#  './data/dataset/data/training_data/85108.txt',
#  './data/dataset/data/training_data/85109.txt',
#  './data/dataset/data/training_data/85110.txt',
#  './data/dataset/data/training_data/85112.txt',
#  './data/dataset/data/training_data/85113.txt',
#  './data/dataset/data/training_data/85114.txt',
#  './data/dataset/data/training_data/85115.txt',
#  './data/dataset/data/training_data/85116.txt',
#  './data/dataset/data/training_data/85118.txt',
#  './data/dataset/data/training_data/85119.txt',
#  './data/dataset/data/training_data/85121.txt',
#  './data/dataset/data/training_data/85122.txt',
#  './data/dataset/data/training_data/85123.txt',
#  './data/dataset/data/training_data/85124.txt',
#  './data/dataset/data/training_data/85127.txt',
#  './data/dataset/data/training_data/85128.txt',
#  './data/dataset/data/training_data/85131.txt',
#  './data/dataset/data/training_data/85132.txt',
#  './data/dataset/data/training_data/85133.txt',
#  './data/dataset/data/training_data/85134.txt',
#  './data/dataset/data/training_data/85135.txt',
#  './data/dataset/data/training_data/85136.txt',
#  './data/dataset/data/training_data/85139.txt',
#  './data/dataset/data/training_data/85140.txt',
#  './data/dataset/data/training_data/85143.txt',
#  './data/dataset/data/training_data/85144.txt',
#  './data/dataset/data/training_data/85145.txt',
#  './data/dataset/data/training_data/85147.txt',
#  './data/dataset/data/training_data/85148.txt',
#  './data/dataset/data/training_data/85150.txt',
#  './data/dataset/data/training_data/85151.txt',
#  './data/dataset/data/training_data/85152.txt',
#  './data/dataset/data/training_data/85153.txt',
#  './data/dataset/data/training_data/85154.txt',
#  './data/dataset/data/training_data/85155.txt',
#  './data/dataset/data/training_data/85157.txt',
#  './data/dataset/data/training_data/85159.txt',
#  './data/dataset/data/training_data/85161.txt',
#  './data/dataset/data/training_data/85162.txt',
#  './data/dataset/data/training_data/85163.txt',
#  './data/dataset/data/training_data/85164.txt',
#  './data/dataset/data/training_data/85165.txt',
#  './data/dataset/data/training_data/85166.txt',
#  './data/dataset/data/training_data/85167.txt',
#  './data/dataset/data/training_data/85168.txt',
#  './data/dataset/data/training_data/85169.txt',
#  './data/dataset/data/training_data/85172.txt',
#  './data/dataset/data/training_data/85174.txt',
#  './data/dataset/data/training_data/85175.txt',
#  './data/dataset/data/training_data/85176.txt',
#  './data/dataset/data/training_data/85180.txt',
#  './data/dataset/data/training_data/85181.txt',
#  './data/dataset/data/training_data/85182.txt',
#  './data/dataset/data/training_data/85184.txt',
#  './data/dataset/data/training_data/85186.txt',
#  './data/dataset/data/training_data/85192.txt',
#  './data/dataset/data/training_data/85196.txt',
#  './data/dataset/data/training_data/85197.txt',
#  './data/dataset/data/training_data/85198.txt',
#  './data/dataset/data/training_data/85199.txt',
#  './data/dataset/data/training_data/85202.txt',
#  './data/dataset/data/training_data/85203.txt',
#  './data/dataset/data/training_data/85207.txt',
#  './data/dataset/data/training_data/85210.txt',
#  './data/dataset/data/training_data/85212.txt',
#  './data/dataset/data/training_data/85213.txt',
#  './data/dataset/data/training_data/85214.txt',
#  './data/dataset/data/training_data/85216.txt',
#  './data/dataset/data/training_data/85217.txt',
#  './data/dataset/data/training_data/85219.txt',
#  './data/dataset/data/training_data/85222.txt',
#  './data/dataset/data/training_data/85225.txt',
#  './data/dataset/data/training_data/85226.txt',
#  './data/dataset/data/training_data/85227.txt',
#  './data/dataset/data/training_data/85229.txt',
#  './data/dataset/data/training_data/85230.txt',
#  './data/dataset/data/training_data/85234.txt',
#  './data/dataset/data/training_data/85235.txt',
#  './data/dataset/data/training_data/85236.txt',
#  './data/dataset/data/training_data/85239.txt',
#  './data/dataset/data/training_data/85240.txt',
#  './data/dataset/data/training_data/85241.txt',
#  './data/dataset/data/training_data/85242.txt',
#  './data/dataset/data/training_data/85243.txt',
#  './data/dataset/data/training_data/85244.txt',
#  './data/dataset/data/training_data/85245.txt',
#  './data/dataset/data/training_data/85246.txt',
#  './data/dataset/data/training_data/85247.txt',
#  './data/dataset/data/training_data/85249.txt',
#  './data/dataset/data/training_data/85250.txt',
#  './data/dataset/data/training_data/85252.txt',
#  './data/dataset/data/training_data/85253.txt',
#  './data/dataset/data/training_data/85258.txt',
#  './data/dataset/data/training_data/85259.txt',
#  './data/dataset/data/training_data/85261.txt',
#  './data/dataset/data/training_data/85262.txt',
#  './data/dataset/data/training_data/85264.txt',
#  './data/dataset/data/training_data/85265.txt',
#  './data/dataset/data/training_data/85269.txt',
#  './data/dataset/data/training_data/85270.txt',
#  './data/dataset/data/training_data/85276.txt',
#  './data/dataset/data/training_data/85277.txt',
#  './data/dataset/data/training_data/85278.txt',
#  './data/dataset/data/training_data/85279.txt',
#  './data/dataset/data/training_data/85282.txt',
#  './data/dataset/data/training_data/85285.txt',
#  './data/dataset/data/training_data/85286.txt',
#  './data/dataset/data/training_data/85287.txt',
#  './data/dataset/data/training_data/85288.txt',
#  './data/dataset/data/training_data/85293.txt',
#  './data/dataset/data/training_data/85294.txt',
#  './data/dataset/data/training_data/85296.txt',
#  './data/dataset/data/training_data/85299.txt',
#  './data/dataset/data/training_data/85300.txt',
#  './data/dataset/data/training_data/85301.txt',
#  './data/dataset/data/training_data/85305.txt',
#  './data/dataset/data/training_data/85306.txt',
#  './data/dataset/data/training_data/85308.txt',
#  './data/dataset/data/training_data/85312.txt',
#  './data/dataset/data/training_data/85313.txt',
#  './data/dataset/data/training_data/85315.txt',
#  './data/dataset/data/training_data/85316.txt',
#  './data/dataset/data/training_data/85317.txt',
#  './data/dataset/data/training_data/85319.txt',
#  './data/dataset/data/training_data/85321.txt',
#  './data/dataset/data/training_data/85322.txt',
#  './data/dataset/data/training_data/85323.txt',
#  './data/dataset/data/training_data/85326.txt',
#  './data/dataset/data/training_data/85327.txt',
#  './data/dataset/data/training_data/85328.txt',
#  './data/dataset/data/training_data/85329.txt',
#  './data/dataset/data/training_data/85331.txt',
#  './data/dataset/data/training_data/85332.txt',
#  './data/dataset/data/training_data/85334.txt',
#  './data/dataset/data/training_data/85335.txt',
#  './data/dataset/data/training_data/85336.txt',
#  './data/dataset/data/training_data/85337.txt',
#  './data/dataset/data/training_data/85338.txt',
#  './data/dataset/data/training_data/85339.txt',
#  './data/dataset/data/training_data/85340.txt',
#  './data/dataset/data/training_data/85341.txt',
#  './data/dataset/data/training_data/85343.txt',
#  './data/dataset/data/training_data/85345.txt',
#  './data/dataset/data/training_data/85349.txt']

# %%
NEW_FREQUENCY = 250
max_len = 0
for i in tqdm.tqdm(range(len(patient_files))):
    # Load the current patient data and recordings.
    current_patient_data = load_patient_data(patient_files[i])
    current_recordings, freq = load_recordings(data_folder, current_patient_data, get_frequencies=True)
    for rec in current_recordings:
        rec_len = (len(rec)/freq) * NEW_FREQUENCY
        if rec_len > max_len:
            max_len = rec_len
# Out:
#   0%|          | 0/942 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Bjorn\Documents\Github\Heart-murmur-detection-2022-private\new_nb_test.ipynb Cell 44 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000043?line=5'>6</a> current_recordings, freq = load_recordings(data_folder, current_patient_data, get_frequencies=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000043?line=6'>7</a> for rec in current_recordings:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000043?line=7'>8</a>     rec_len = (len(rec)/freq) * NEW_FREQUENCY
#       <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000043?line=8'>9</a>     if rec_len > max_len:
#      <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000043?line=9'>10</a>         max_len = rec_len
#
# TypeError: unsupported operand type(s) for /: 'int' and 'list'

# %%
rec_len
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Bjorn\Documents\Github\Heart-murmur-detection-2022-private\new_nb_test.ipynb Cell 45 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000044?line=0'>1</a> rec_len
#
# NameError: name 'rec_len' is not defined

# %%
freq
# Out:
# [4000, 4000, 4000, 4000]

# %%
len(rec)/freq
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Bjorn\Documents\Github\Heart-murmur-detection-2022-private\new_nb_test.ipynb Cell 46 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bjorn/Documents/Github/Heart-murmur-detection-2022-private/new_nb_test.ipynb#ch0000045?line=0'>1</a> len(rec)/freq
#
# TypeError: unsupported operand type(s) for /: 'int' and 'list'

# %%
for indx, rec in enumerate(current_recordings):
    print(len(rec)//freq[indx]*NEW_FREQUENCY)
# Out:
# 5750
# 3250
# 3500
# 6500
