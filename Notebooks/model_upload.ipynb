# %%
import tensorflow as tf

# %%
def _inception_module(input_tensor, stride=1, activation='linear', use_bottleneck=True, kernel_size=40, bottleneck_size=32, nb_filters=32):

    if use_bottleneck and int(input_tensor.shape[-1]) > 1:
        input_inception = tf.keras.layers.Conv1D(filters=bottleneck_size, kernel_size=1,
                                              padding='same', activation=activation, use_bias=False)(input_tensor)
    else:
        input_inception = input_tensor

    # kernel_size_s = [3, 5, 8, 11, 17]
    kernel_size_s = [kernel_size // (2 ** i) for i in range(3)]

    conv_list = []

    for i in range(len(kernel_size_s)):
        conv_list.append(tf.keras.layers.Conv1D(filters=nb_filters, kernel_size=kernel_size_s[i],
                                              strides=stride, padding='same', activation=activation, use_bias=False)(
            input_inception))

    max_pool_1 = tf.keras.layers.MaxPool1D(pool_size=3, strides=stride, padding='same')(input_tensor)

    conv_6 = tf.keras.layers.Conv1D(filters=nb_filters, kernel_size=1,
                                  padding='same', activation=activation, use_bias=False)(max_pool_1)

    conv_list.append(conv_6)

    x = tf.keras.layers.Concatenate(axis=2)(conv_list)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation='relu')(x)
    return x

def _shortcut_layer(input_tensor, out_tensor):
    shortcut_y = tf.keras.layers.Conv1D(filters=int(out_tensor.shape[-1]), kernel_size=1,
                                      padding='same', use_bias=False)(input_tensor)
    shortcut_y = tf.keras.layers.BatchNormalization()(shortcut_y)

    x = tf.keras.layers.Add()([shortcut_y, out_tensor])
    x = tf.keras.layers.Activation('relu')(x)
    return x

def base_model(sig_len,n_features, depth=10, use_residual=True):
    input_layer = tf.keras.layers.Input(shape=(sig_len,n_features))

    x = input_layer
    input_res = input_layer

    for d in range(depth):

        x = _inception_module(x)

        if use_residual and d % 3 == 2:
            x = _shortcut_layer(input_res, x)
            input_res = x

    gap_layer = tf.keras.layers.GlobalAveragePooling1D()(x)

    output = tf.keras.layers.Dense(1, activation='sigmoid')(gap_layer)

    model = tf.keras.models.Model(inputs=input_layer, outputs=output)
    return model


def build_murmur_model(sig_len,n_features, depth=10, use_residual=True):
    input_layer = tf.keras.layers.Input(shape=(sig_len,n_features))

    x = input_layer
    input_res = input_layer

    for d in range(depth):

        x = _inception_module(x)

        if use_residual and d % 3 == 2:
            x = _shortcut_layer(input_res, x)
            input_res = x

    gap_layer = tf.keras.layers.GlobalAveragePooling1D()(x)

    murmur_output = tf.keras.layers.Dense(3, activation='softmax', name="murmur_output")(gap_layer)
    #clinical_output = tf.keras.layers.Dense(1, activation='sigmoid', name="clinical_output")(gap_layer)

    model = tf.keras.models.Model(inputs=input_layer, outputs=murmur_output)
    model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = [tf.keras.metrics.CategoricalAccuracy(),
    tf.keras.metrics.AUC(curve='ROC')])
    return model

def build_clinical_model(sig_len,n_features, depth=10, use_residual=True):
    input_layer = tf.keras.layers.Input(shape=(sig_len,n_features))

    x = input_layer
    input_res = input_layer

    for d in range(depth):

        x = _inception_module(x)

        if use_residual and d % 3 == 2:
            x = _shortcut_layer(input_res, x)
            input_res = x

    gap_layer = tf.keras.layers.GlobalAveragePooling1D()(x)

    clinical_output = tf.keras.layers.Dense(1, activation='sigmoid', name="clinical_output")(gap_layer)

    model = tf.keras.models.Model(inputs=input_layer, outputs=clinical_output)
    model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = [tf.keras.metrics.BinaryAccuracy(),
    tf.keras.metrics.AUC(curve='ROC')])
    
    return model


def get_lead_index(patient_metadata):    
    lead_name = []
    lead_num = []
    cnt = 0
    for i in patient_metadata.splitlines(): 
        if i.split(" ")[0] == "AV" or i.split(" ")[0] == "PV" or i.split(" ")[0] == "TV" or i.split(" ")[0] == "MV":
            if not i.split(" ")[0] in lead_name:
                lead_name.append(i.split(" ")[0])
                lead_num.append(cnt)
            cnt += 1
    return np.asarray(lead_num)

def scheduler(epoch, lr):
    if epoch == 10:
        return lr * 0.1
    elif epoch == 15:
        return lr * 0.1
    elif epoch == 20:
        return lr * 0.1
    else:
        return lr

def get_murmur_locations(data):
    murmur_location = None
    for l in data.split('\n'):
        if l.startswith('#Murmur locations:'):
            try:
                murmur_location = l.split(': ')[1]
            except:
                pass
    if murmur_location is None:
        raise ValueError('No outcome available. Is your code trying to load labels from the hidden data?')
    return murmur_location

def pad_array(data):
    max_len = 0
    for i in data:
        if len(i) > max_len:
            max_len = len(i)
    new_arr = np.zeros((len(data),max_len))
    for j in range(len(data)):
        new_arr[j,:len(data[j])] = data[j]
    return new_arr

# %%
model = base_model(32256//5,1, depth=10, use_residual=True)

# %%
model.load_weights("pretrained_model.h5")

# %%
#model = build_clinical_model(32256//5,2, depth=10, use_residual=True)

# %%
x = tf.keras.layers.Dense(3, "softmax",  name="murmur_output")(model.layers[-2].output)

# %%
model2 = tf.keras.Model(inputs=model.layers[0].output, outputs=[x])
model2.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 6451, 1)]    0           []
#
#  max_pooling1d_80 (MaxPooling1D  (None, 6451, 1)     0           ['input_12[0][0]']
#  )
#
#  conv1d_423 (Conv1D)            (None, 6451, 32)     1280        ['input_12[0][0]']
#
#  conv1d_424 (Conv1D)            (None, 6451, 32)     640         ['input_12[0][0]']
#
#  conv1d_425 (Conv1D)            (None, 6451, 32)     320         ['input_12[0][0]']
#
#  conv1d_426 (Conv1D)            (None, 6451, 32)     32          ['max_pooling1d_80[0][0]']
#
#  concatenate_80 (Concatenate)   (None, 6451, 128)    0           ['conv1d_423[0][0]',
#                                                                   'conv1d_424[0][0]',
#                                                                   'conv1d_425[0][0]',
#                                                                   'conv1d_426[0][0]']
#
#  batch_normalization_104 (Batch  (None, 6451, 128)   512         ['concatenate_80[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 6451, 128)    0           ['batch_normalization_104[0][0]']
#
#  conv1d_427 (Conv1D)            (None, 6451, 32)     4096        ['activation_104[0][0]']
#
#  max_pooling1d_81 (MaxPooling1D  (None, 6451, 128)   0           ['activation_104[0][0]']
#  )
#
#  conv1d_428 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_427[0][0]']
#
#  conv1d_429 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_427[0][0]']
#
#  conv1d_430 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_427[0][0]']
#
#  conv1d_431 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_81[0][0]']
#
#  concatenate_81 (Concatenate)   (None, 6451, 128)    0           ['conv1d_428[0][0]',
#                                                                   'conv1d_429[0][0]',
#                                                                   'conv1d_430[0][0]',
#                                                                   'conv1d_431[0][0]']
#
#  batch_normalization_105 (Batch  (None, 6451, 128)   512         ['concatenate_81[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 6451, 128)    0           ['batch_normalization_105[0][0]']
#
#  conv1d_432 (Conv1D)            (None, 6451, 32)     4096        ['activation_105[0][0]']
#
#  max_pooling1d_82 (MaxPooling1D  (None, 6451, 128)   0           ['activation_105[0][0]']
#  )
#
#  conv1d_433 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_432[0][0]']
#
#  conv1d_434 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_432[0][0]']
#
#  conv1d_435 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_432[0][0]']
#
#  conv1d_436 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_82[0][0]']
#
#  concatenate_82 (Concatenate)   (None, 6451, 128)    0           ['conv1d_433[0][0]',
#                                                                   'conv1d_434[0][0]',
#                                                                   'conv1d_435[0][0]',
#                                                                   'conv1d_436[0][0]']
#
#  conv1d_437 (Conv1D)            (None, 6451, 128)    128         ['input_12[0][0]']
#
#  batch_normalization_106 (Batch  (None, 6451, 128)   512         ['concatenate_82[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 6451, 128)   512         ['conv1d_437[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 6451, 128)    0           ['batch_normalization_106[0][0]']
#
#  add_24 (Add)                   (None, 6451, 128)    0           ['batch_normalization_107[0][0]',
#                                                                   'activation_106[0][0]']
#
#  activation_107 (Activation)    (None, 6451, 128)    0           ['add_24[0][0]']
#
#  conv1d_438 (Conv1D)            (None, 6451, 32)     4096        ['activation_107[0][0]']
#
#  max_pooling1d_83 (MaxPooling1D  (None, 6451, 128)   0           ['activation_107[0][0]']
#  )
#
#  conv1d_439 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_438[0][0]']
#
#  conv1d_440 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_438[0][0]']
#
#  conv1d_441 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_438[0][0]']
#
#  conv1d_442 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_83[0][0]']
#
#  concatenate_83 (Concatenate)   (None, 6451, 128)    0           ['conv1d_439[0][0]',
#                                                                   'conv1d_440[0][0]',
#                                                                   'conv1d_441[0][0]',
#                                                                   'conv1d_442[0][0]']
#
#  batch_normalization_108 (Batch  (None, 6451, 128)   512         ['concatenate_83[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 6451, 128)    0           ['batch_normalization_108[0][0]']
#
#  conv1d_443 (Conv1D)            (None, 6451, 32)     4096        ['activation_108[0][0]']
#
#  max_pooling1d_84 (MaxPooling1D  (None, 6451, 128)   0           ['activation_108[0][0]']
#  )
#
#  conv1d_444 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_443[0][0]']
#
#  conv1d_445 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_443[0][0]']
#
#  conv1d_446 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_443[0][0]']
#
#  conv1d_447 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_84[0][0]']
#
#  concatenate_84 (Concatenate)   (None, 6451, 128)    0           ['conv1d_444[0][0]',
#                                                                   'conv1d_445[0][0]',
#                                                                   'conv1d_446[0][0]',
#                                                                   'conv1d_447[0][0]']
#
#  batch_normalization_109 (Batch  (None, 6451, 128)   512         ['concatenate_84[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 6451, 128)    0           ['batch_normalization_109[0][0]']
#
#  conv1d_448 (Conv1D)            (None, 6451, 32)     4096        ['activation_109[0][0]']
#
#  max_pooling1d_85 (MaxPooling1D  (None, 6451, 128)   0           ['activation_109[0][0]']
#  )
#
#  conv1d_449 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_448[0][0]']
#
#  conv1d_450 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_448[0][0]']
#
#  conv1d_451 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_448[0][0]']
#
#  conv1d_452 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_85[0][0]']
#
#  concatenate_85 (Concatenate)   (None, 6451, 128)    0           ['conv1d_449[0][0]',
#                                                                   'conv1d_450[0][0]',
#                                                                   'conv1d_451[0][0]',
#                                                                   'conv1d_452[0][0]']
#
#  conv1d_453 (Conv1D)            (None, 6451, 128)    16384       ['activation_107[0][0]']
#
#  batch_normalization_110 (Batch  (None, 6451, 128)   512         ['concatenate_85[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 6451, 128)   512         ['conv1d_453[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 6451, 128)    0           ['batch_normalization_110[0][0]']
#
#  add_25 (Add)                   (None, 6451, 128)    0           ['batch_normalization_111[0][0]',
#                                                                   'activation_110[0][0]']
#
#  activation_111 (Activation)    (None, 6451, 128)    0           ['add_25[0][0]']
#
#  conv1d_454 (Conv1D)            (None, 6451, 32)     4096        ['activation_111[0][0]']
#
#  max_pooling1d_86 (MaxPooling1D  (None, 6451, 128)   0           ['activation_111[0][0]']
#  )
#  conv1d_455 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_454[0][0]']
#
#  conv1d_456 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_454[0][0]']
#
#  conv1d_457 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_454[0][0]']
#
#  conv1d_458 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_86[0][0]']
#
#  concatenate_86 (Concatenate)   (None, 6451, 128)    0           ['conv1d_455[0][0]',
#                                                                   'conv1d_456[0][0]',
#                                                                   'conv1d_457[0][0]',
#                                                                   'conv1d_458[0][0]']
#
#  batch_normalization_112 (Batch  (None, 6451, 128)   512         ['concatenate_86[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 6451, 128)    0           ['batch_normalization_112[0][0]']
#
#  conv1d_459 (Conv1D)            (None, 6451, 32)     4096        ['activation_112[0][0]']
#
#  max_pooling1d_87 (MaxPooling1D  (None, 6451, 128)   0           ['activation_112[0][0]']
#  )
#
#  conv1d_460 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_459[0][0]']
#
#  conv1d_461 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_459[0][0]']
#
#  conv1d_462 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_459[0][0]']
#
#  conv1d_463 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_87[0][0]']
#
#  concatenate_87 (Concatenate)   (None, 6451, 128)    0           ['conv1d_460[0][0]',
#                                                                   'conv1d_461[0][0]',
#                                                                   'conv1d_462[0][0]',
#                                                                   'conv1d_463[0][0]']
#
#  batch_normalization_113 (Batch  (None, 6451, 128)   512         ['concatenate_87[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 6451, 128)    0           ['batch_normalization_113[0][0]']
#
#  conv1d_464 (Conv1D)            (None, 6451, 32)     4096        ['activation_113[0][0]']
#
#  max_pooling1d_88 (MaxPooling1D  (None, 6451, 128)   0           ['activation_113[0][0]']
#  )
#
#  conv1d_465 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_464[0][0]']
#
#  conv1d_466 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_464[0][0]']
#
#  conv1d_467 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_464[0][0]']
#
#  conv1d_468 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_88[0][0]']
#
#  concatenate_88 (Concatenate)   (None, 6451, 128)    0           ['conv1d_465[0][0]',
#                                                                   'conv1d_466[0][0]',
#                                                                   'conv1d_467[0][0]',
#                                                                   'conv1d_468[0][0]']
#
#  conv1d_469 (Conv1D)            (None, 6451, 128)    16384       ['activation_111[0][0]']
#
#  batch_normalization_114 (Batch  (None, 6451, 128)   512         ['concatenate_88[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 6451, 128)   512         ['conv1d_469[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 6451, 128)    0           ['batch_normalization_114[0][0]']
#
#  add_26 (Add)                   (None, 6451, 128)    0           ['batch_normalization_115[0][0]',
#                                                                   'activation_114[0][0]']
#
#  activation_115 (Activation)    (None, 6451, 128)    0           ['add_26[0][0]']
#
#  conv1d_470 (Conv1D)            (None, 6451, 32)     4096        ['activation_115[0][0]']
#
#  max_pooling1d_89 (MaxPooling1D  (None, 6451, 128)   0           ['activation_115[0][0]']
#  )
#
#  conv1d_471 (Conv1D)            (None, 6451, 32)     40960       ['conv1d_470[0][0]']
#
#  conv1d_472 (Conv1D)            (None, 6451, 32)     20480       ['conv1d_470[0][0]']
#  conv1d_473 (Conv1D)            (None, 6451, 32)     10240       ['conv1d_470[0][0]']
#
#  conv1d_474 (Conv1D)            (None, 6451, 32)     4096        ['max_pooling1d_89[0][0]']
#
#  concatenate_89 (Concatenate)   (None, 6451, 128)    0           ['conv1d_471[0][0]',
#                                                                   'conv1d_472[0][0]',
#                                                                   'conv1d_473[0][0]',
#                                                                   'conv1d_474[0][0]']
#
#  batch_normalization_116 (Batch  (None, 6451, 128)   512         ['concatenate_89[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 6451, 128)    0           ['batch_normalization_116[0][0]']
#
#  global_average_pooling1d_8 (Gl  (None, 128)         0           ['activation_116[0][0]']
#  obalAveragePooling1D)
#
#  murmur_output (Dense)          (None, 3)            387         ['global_average_pooling1d_8[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 761,059
# Trainable params: 757,731
# Non-trainable params: 3,328
# __________________________________________________________________________________________________
